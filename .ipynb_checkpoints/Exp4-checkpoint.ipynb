# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment4(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=1000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp4', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df, df2

# %%
#changeable parameters
np.random.seed(5566)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df, df2 = set_experiment4(price_list=price_list, segments=segments, update_freq =10, T=T)
# Out:
# The highest true optimal is 9
# The lowest true optimal is: 3
# time: 26.836484670639038

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 429
# Detected Sign: -1
# Reward change detected at time: 462
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 492
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 514
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 649
# Detected Sign: -1
# Reward change detected at time: 867
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 916
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 938
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 960
# Detected Sign: 1
# Reward change detected at time: 1141
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1443
# Detected Sign: -1
# Reward change detected at time: 1874
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1895
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1930
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1951
# Detected Sign: 1
# trial 0 IDS_1 time: 207.60058879852295
# Reward change detected at time: 416
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 454
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 548
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 861
# Detected Sign: 1
# Reward change detected at time: 1310
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1335
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1932
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1989
# Detected Sign: 1
# Detector cooling
# trial 1 IDS_1 time: 117.86737585067749
# Reward change detected at time: 425
# Detected Sign: 1
# Reward change detected at time: 470
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 493
# Detected Sign: -1
# Reward change detected at time: 877
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 910
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 943
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1480
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1865
# Detected Sign: 1
# Reward change detected at time: 1910
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1931
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1952
# Detected Sign: 1
# Detector cooling
# trial 2 IDS_1 time: 151.51194190979004
# Reward change detected at time: 359
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 459
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 871
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 892
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 918
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 939
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 988
# Detected Sign: -1
# Reward change detected at time: 1331
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1689
# Detected Sign: -1
# Reward change detected at time: 1870
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1908
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1929
# Detected Sign: 1
# Detector cooling
# trial 3 IDS_1 time: 165.56626987457275
# Reward change detected at time: 483
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 521
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 610
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 827
# Detected Sign: -1
# Reward change detected at time: 1016
# Detected Sign: 1
# Reward change detected at time: 1546
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1640
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1878
# Detected Sign: -1
# Detector cooling
# Detector cooling
# trial 4 IDS_1 time: 513.7888951301575
# Reward change detected at time: 494
# Detected Sign: -1
# Reward change detected at time: 566
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 855
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 877
# Detected Sign: -1
# Reward change detected at time: 901
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 933
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 963
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 984
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1011
# Detected Sign: -1
# Reward change detected at time: 1580
# Detected Sign: -1
# Reward change detected at time: 1881
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 857
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 891
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 929
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 969
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 994
# Detected Sign: -1
# Reward change detected at time: 1371
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1446
# Detected Sign: -1
# Reward change detected at time: 1596
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1843
# Detected Sign: -1
# Reward change detected at time: 1875
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1900
# Detected Sign: 1
# Reward change detected at time: 1937
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1963
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 5 IDST_1 time: 5292.946321964264
# Reward change detected at time: 427
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 458
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 483
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 680
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 873
# Detected Sign: 1
# Reward change detected at time: 1357
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1455
# Detected Sign: -1
# Reward change detected at time: 1882
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1919
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1943
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 6 IDST_1 time: 5724.394185304642
# Reward change detected at time: 421
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 446
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 468
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 533
# Detected Sign: -1
# Reward change detected at time: 616
# Detected Sign: -1
# Reward change detected at time: 869
# Detected Sign: 1
# Reward change detected at time: 898
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 932
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 956
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 979
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1306
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1358
# Detected Sign: -1
# Reward change detected at time: 1886
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1919
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1951
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 7 IDST_1 time: 328.59499502182007
# Reward change detected at time: 135
# Detected Sign: 1
# Reward change detected at time: 350
# Detected Sign: -1
# Reward change detected at time: 694
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 877
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 908
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 934
# Detected Sign: -1
# Reward change detected at time: 1673
# Detected Sign: -1
# Reward change detected at time: 1881
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1975
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 8 IDST_1 time: 200.5477111339569
# Reward change detected at time: 449
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 473
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 838
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 900
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 932
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1681
# Detected Sign: -1
# Reward change detected at time: 1881
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1910
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1942
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 9 IDST_1 time: 183.79841089248657

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 370
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 409
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 431
# Detected Sign: -1
# Reward change detected at time: 836
# Detected Sign: -1
# Reward change detected at time: 860
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 893
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 954
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1360
# Detected Sign: -1
# Reward change detected at time: 1385
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1639
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1839
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1860
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1919
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1940
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1961
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 0 IDS_2 time: 208.03286027908325
# Reward change detected at time: 393
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 414
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 472
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 618
# Detected Sign: -1
# Reward change detected at time: 868
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 906
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 927
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 949
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 970
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 991
# Detected Sign: 1
# Reward change detected at time: 1312
# Detected Sign: -1
# Reward change detected at time: 1341
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1419
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1500
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1612
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1637
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1748
# Detected Sign: -1
# Reward change detected at time: 1900
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1947
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 1 IDS_2 time: 261.7827887535095
# Reward change detected at time: 459
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 481
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 525
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 883
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 908
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 933
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 956
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time:
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 4 IDS_3 time: 152.55997514724731
# Reward change detected at time: 414
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 488
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 513
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 836
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 858
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 894
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 937
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 958
# Detected Sign: -1
# Reward change detected at time: 1409
# Detected Sign: -1
# Reward change detected at time: 1639
# Detected Sign: -1
# Reward change detected at time: 1857
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1878
# Detected Sign: 1
# Reward change detected at time: 1911
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1938
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1972
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 5 IDS_3 time: 204.5492067337036
# Reward change detected at time: 444
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 465
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 486
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 507
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 847
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 885
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 908
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 934
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 955
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1361
# Detected Sign: -1
# Reward change detected at time: 1841
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1877
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1912
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1934
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1959
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1980
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 6 IDS_3 time: 216.70507407188416
# Reward change detected at time: 356
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 450
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 478
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 879
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 906
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 930
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1040
# Detected Sign: 1
# Reward change detected at time: 1392
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1491
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1886
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1915
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 7 IDS_3 time: 157.51609706878662
# Reward change detected at time: 424
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 471
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 497
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 874
# Detected Sign: 1
# Reward change detected at time: 928
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 949
# Detected Sign: -1
# Reward change detected at time: 973
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1360
# Detected Sign: -1
# Reward change detected at time: 1593
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1628
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1868
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1901
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1922
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1943
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1964
# Detected Sign: 1
# trial 8 IDS_3 time: 205.18243193626404
# Reward change detected at time: 450
# Detected Sign: -1
# Reward change detected at time: 863
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 886
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 911
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 937
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1047
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1703
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1903
# Detected Sign: 1
# Reward change detected at time: 1939
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 9 IDS_3 time: 126.1883659362793

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=4, bias=0, UCB1=False, tuned=False)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.8536641597747803
# trial 1 UCB_1 time: 0.7967538833618164
# trial 2 UCB_1 time: 0.8496179580688477
# trial 3 UCB_1 time: 0.9152562618255615
# trial 4 UCB_1 time: 0.7681090831756592
# trial 5 UCB_1 time: 0.7652699947357178
# trial 6 UCB_1 time: 0.7729518413543701
# trial 7 UCB_1 time: 0.7698159217834473
# trial 8 UCB_1 time: 0.7469010353088379
# trial 9 UCB_1 time: 0.7466349601745605
# trial 0 UCB_2 time: 0.7525613307952881
# trial 1 UCB_2 time: 0.7583119869232178
# trial 2 UCB_2 time: 0.7697370052337646
# trial 3 UCB_2 time: 0.7521133422851562
# trial 4 UCB_2 time: 0.7531130313873291
# trial 5 UCB_2 time: 0.74314284324646
# trial 6 UCB_2 time: 0.752338171005249
# trial 7 UCB_2 time: 0.7391769886016846
# trial 8 UCB_2 time: 0.7579529285430908
# trial 9 UCB_2 time: 0.7429869174957275
# trial 0 UCB-tuned time: 1.337886095046997
# trial 1 UCB-tuned time: 1.4547979831695557
# trial 2 UCB-tuned time: 1.4270098209381104
# trial 3 UCB-tuned time: 1.4800012111663818
# trial 4 UCB-tuned time: 1.3520047664642334
# trial 5 UCB-tuned time: 1.2752761840820312
# trial 6 UCB-tuned time: 1.3062646389007568
# trial 7 UCB-tuned time: 1.2704598903656006
# trial 8 UCB-tuned time: 1.3697307109832764
# trial 9 UCB-tuned time: 1.3057861328125
# trial 0 UCBPI time: 0.7396218776702881
# trial 1 UCBPI time: 0.7491791248321533
# trial 2 UCBPI time: 0.7490429878234863
# trial 3 UCBPI time: 0.7412841320037842
# trial 4 UCBPI time: 0.7477540969848633
# trial 5 UCBPI time: 0.7440199851989746
# trial 6 UCBPI time: 0.735802173614502
# trial 7 UCBPI time: 0.746441125869751
# trial 8 UCBPI time: 0.7401859760284424
# trial 9 UCBPI time: 0.7395968437194824
# trial 0 TS time: 1.5414559841156006
# trial 1 TS time: 1.6070020198822021
# trial 2 TS time: 1.5633370876312256
# trial 3 TS time: 1.5576066970825195
# trial 4 TS time: 1.557283878326416
# trial 5 TS time: 1.5109200477600098
# trial 6 TS time: 1.5887951850891113
# trial 7 TS time: 1.493304967880249
# trial 8 TS time: 1.6215741634368896
# trial 9 TS time: 1.6140861511230469
# trial 0 EG 0.05 time: 0.1479480266571045
# trial 1 EG 0.05 time: 0.14065909385681152
# trial 2 EG 0.05 time: 0.1390368938446045
# trial 3 EG 0.05 time: 0.15590786933898926
# trial 4 EG 0.05 time: 0.1502399444580078
# trial 5 EG 0.05 time: 0.15770268440246582
# trial 6 EG 0.05 time: 0.14880633354187012
# trial 7 EG 0.05 time: 0.14613699913024902
# trial 8 EG 0.05 time: 0.13908910751342773
# trial 9 EG 0.05 time: 0.14997601509094238
# trial 0 EG 0.1 time: 0.14570307731628418
# trial 1 EG 0.1 time: 0.14569878578186035
# trial 2 EG 0.1 time: 0.14887714385986328
# trial 3 EG 0.1 time: 0.15010476112365723
# trial 4 EG 0.1 time: 0.15049386024475098
# trial 5 EG 0.1 time: 0.14351797103881836
# trial 6 EG 0.1 time: 0.14559626579284668
# trial 7 EG 0.1 time: 0.14769291877746582
# trial 8 EG 0.1 time: 0.14623188972473145
# trial 9 EG 0.1 time: 0.14649176597595215
# trial 0 EG 0.15 time: 0.13956880569458008
# trial 1 EG 0.15 time: 0.14425015449523926
# trial 2 EG 0.15 time: 0.14631295204162598
# trial 3 EG 0.15 time: 0.14125609397888184
# trial 4 EG 0.15 time: 0.13980793952941895
# trial 5 EG 0.15 time: 0.13931798934936523
# trial 6 EG 0.15 time: 0.15506505966186523
# trial 7 EG 0.15 time: 0.1482858657836914
# trial 8 EG 0.15 time: 0.14510488510131836
# trial 9 EG 0.15 time: 0.14882469177246094

# %%
def draw_exp_graph(IDS_1, IDS_2, IDS_3, IDST_1, UCB_1, UCB_2, UCBT, UCBPI, TS, EG_1, EG_2, EG_3, title):
    
    IDS_1_mean = IDS_1.mean()
    IDS_2_mean = IDS_2.mean()
    IDS_3_mean = IDS_3.mean()
    IDST_1_mean = IDST_1.mean()
    UCB_1_mean = UCB_1.mean()
    UCB_2_mean =UCB_2.mean()
    UCBT_mean = UCBT.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_1_mean = EG_1.mean()
    EG_2_mean = EG_2.mean()
    EG_3_mean = EG_3.mean()
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.fill_between(T, EG_1.min(), EG_1.max(), color='#000000', alpha=0.2)
    
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')
    plt.fill_between(T, EG_2.min(), EG_2.max(), color='#000000', alpha=0.2)
    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    plt.fill_between(T, EG_3.min(), EG_3.max(), color='#000000', alpha=0.2)
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    plt.fill_between(T, TS.min(), TS.max(), color='#666666', alpha=0.2)
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.fill_between(T, UCB_1.min(), UCB_1.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.fill_between(T, UCB_2.min(), UCB_2.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.fill_between(T, UCBT.min(), UCBT.max(), color='#666600', alpha=0.2)

    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='#666600', alpha=0.2)

    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.fill_between(T, IDS_2.min(), IDS_2.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.fill_between(T, IDS_3.min(), IDS_3.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='#FF6666', alpha=0.2)
    
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned', 'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2', 'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Reward')
    plt.show()

# %%
title = 'Case 4: Seasonality'
draw_exp_graph(IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title)

# %%
def value_exp4(t, T=2000, size=10000):
    seg = np.random.choice(exp_MAB_1.seg_means.size, size, replace=True)
    shift = 0.3 * np.sin(np.pi*4*t/T)
    value = exp_MAB_1.seg_means[seg] + np.random.normal(0, 0.1, size) + shift
    return value

def optimal_reward(T, size=10000):
    optimal_arm_per = np.zeros(T)
    optimal_reward_per = np.zeros(T)
    for t in range(T):
        optimal_arm = 0
        optimal_reward_t = 0
        for k, p in enumerate(price_list):
            expect_reward = sum(value_exp4(t, size=size) > p) * p / size * 10
            if expect_reward > optimal_reward_t:
                optimal_reward_t = expect_reward
                optimal_arm = k
        optimal_reward_per[t] = optimal_reward_t
        optimal_arm_per[t] = optimal_arm
    return optimal_arm_per, optimal_reward_per

# %%
optimal_arm_per, optimal_reward_per = optimal_reward(2000)

# %%
optimal_reward = pd.DataFrame(optimal_reward_per).T.cumsum(axis=1)
draw_regret(optimal_reward, IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title, bounds=True)

# %%
draw_arm_withopt(IDS_1_df_arm, TS_df_arm, UCB_2_df_arm, EG_2_df_arm, optimal_arm_per)
