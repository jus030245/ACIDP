# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment4(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=1000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp4', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df, df2

# %%
#changeable parameters
np.random.seed(5566)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df, df2 = set_experiment4(price_list=price_list, segments=segments, update_freq =10, T=T)
# Out:
# The highest true optimal is 9
# The lowest true optimal is: 3
# time: 31.812458038330078

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 429
# Detected Sign: -1
# Reward change detected at time: 462
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 492
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 514
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 649
# Detected Sign: -1
# Reward change detected at time: 867
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 916
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 938
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 960
# Detected Sign: 1
# Reward change detected at time: 1141
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1443
# Detected Sign: -1
# Reward change detected at time: 1874
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1895
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1930
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1951
# Detected Sign: 1
# trial 0 IDS_1 time: 250.10526585578918
# Reward change detected at time: 475
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 517
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 539
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 604
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 855
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 941
# Detected Sign: 1
# Reward change detected at time: 1382
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1464
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1821
# Detected Sign: 1
# Reward change detected at time: 1845
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1898
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 1 IDS_1 time: 183.55485606193542
# Reward change detected at time: 450
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 471
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 492
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 705
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 843
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1009
# Detected Sign: 1
# Reward change detected at time: 1838
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1870
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1967
# Detected Sign: 1
# trial 2 IDS_1 time: 152.71705389022827
# Reward change detected at time: 125
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 374
# Detected Sign: -1
# Reward change detected at time: 858
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 882
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 954
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1390
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1911
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1937
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1974
# Detected Sign: 1
# Detector cooling
# trial 3 IDS_1 time: 154.49994492530823
# Reward change detected at time: 412
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 434
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 464
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 488
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 514
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 894
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 915
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 936
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1281
# Detected Sign: 1
# Reward change detected at time: 1358
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1561
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1886
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1918
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 4 IDS_1 time: 216.9066879749298
# Reward change detected at time: 443
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 523
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 563
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 881
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 902
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 923
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 944
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1354
# Detected Sign: -1
# Reward change detected at time: 1888
# Detected Sign: 1
# Reward change detected at time: 1912
# Detected Sign: 1
# Detector cooling
# trial 5 IDS_1 time: 168.0229949951172
# Reward change detected at time: 409
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 430
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 464
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 959
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1375
# Detected Sign: -1
# Reward change detected at time: 1457
# Detected Sign: -1
# Reward change detected at time: 1652
# Detected Sign: -1
# Reward change detected at time: 1820
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1846
# Detected Sign: 1
# Reward change detected at time: 1886
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1913
# Detected Sign: -1
# trial 6 IDS_1 time: 182.56297826766968
# Reward change detected at time: 137
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 386
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 446
# Detected Sign: -1
# Reward change detected at time: 885
# Detected Sign: 1
# Reward change detected at time: 915
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 939
# Detected Sign: 1
# Reward change detected at time: 1024
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1356
# Detected Sign: -1
# Reward change detected at time: 1396
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1618
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 8 IDST_1 time: 237.2971978187561
# Reward change detected at time: 457
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 481
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 796
# Detected Sign: -1
# Reward change detected at time: 876
# Detected Sign: 1
# Reward change detected at time: 898
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 928
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1390
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1455
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1681
# Detected Sign: -1
# Reward change detected at time: 1831
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1899
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1924
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1945
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1969
# Detected Sign: 1
# trial 9 IDST_1 time: 265.2799060344696

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 422
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 443
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 470
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 830
# Detected Sign: -1
# Reward change detected at time: 876
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 909
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1072
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1392
# Detected Sign: -1
# Reward change detected at time: 1801
# Detected Sign: -1
# Reward change detected at time: 1854
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1882
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1906
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 0 IDS_2 time: 163.1567039489746
# Reward change detected at time: 309
# Detected Sign: 1
# Reward change detected at time: 353
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 379
# Detected Sign: -1
# Reward change detected at time: 400
# Detected Sign: -1
# Reward change detected at time: 595
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 867
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 889
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 910
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 938
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1083
# Detected Sign: 1
# Reward change detected at time: 1388
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1560
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1837
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1862
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1918
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 1 IDS_2 time: 205.0751349925995
# Reward change detected at time: 421
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 452
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 483
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 543
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 941
# Detected Sign: 1
# Reward change detected at time: 1337
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1475
# Detected Sign: -1
# Reward change detected at time: 1500
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1868
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 2 IDS_2 time: 125.8042984008789
# Reward change detected at time: 410
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 487
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 689
# Detected Sign: -1
# Reward change detected at time: 845
# Detected Sign: -1
# Reward change detected at time: 887
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 911
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 935
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 956
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1338
# Detected Sign: -1
# Reward change detected at time: 1791
# Detected Sign: -1
# Reward change detected at time: 1870
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1897
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1918
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 3 IDS_2 time: 176.43118000030518
# Reward change detected at time: 362
# Detected Sign: 1
# Reward change detected at time: 441
# Detected Sign: -1
# Reward change detected at time: 912
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1046
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1067
# Detected Sign: 1
# Reward change detected at time: 1320
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1476
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1889
# Detected Sign: 1
# Reward change detected at time: 1934
# Detected Sign: 1
# trial 4 IDS_2 time: 125.76632690429688
# Reward change detected at time: 378
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 458
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 487
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 586
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 610
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 793
# Detected Sign: -1
# Reward change detected at time: 990
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1597
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1622
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1834
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1908
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 5 IDS_2 time: 152.24093008041382
# Reward change detected at time: 373
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 491
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 587
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 894
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1358
# Detected Sign: -1
# Reward change detected at time: 1470
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1623
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1851
# Detected Sign: 1
# Reward change detected at time: 1876
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1904
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1925
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1953
# Detected Sign: -1
# trial 6 IDS_2 time: 162.44241213798523
# Reward change detected at time: 403
# Detected Sign: -1
# Reward change detected at time: 439
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 871
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 899
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 921
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 881
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 902
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1537
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1558
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1906
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 9 IDS_3 time: 161.8421700000763

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=False, tuned=True)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.7724602222442627
# trial 1 UCB_1 time: 0.7640402317047119
# trial 2 UCB_1 time: 0.7711260318756104
# trial 3 UCB_1 time: 0.765988826751709
# trial 4 UCB_1 time: 0.7697591781616211
# trial 5 UCB_1 time: 0.771373987197876
# trial 6 UCB_1 time: 0.7670328617095947
# trial 7 UCB_1 time: 0.7671232223510742
# trial 8 UCB_1 time: 0.7661318778991699
# trial 9 UCB_1 time: 0.7671878337860107
# trial 0 UCB_2 time: 0.7673919200897217
# trial 1 UCB_2 time: 0.7772109508514404
# trial 2 UCB_2 time: 0.7999229431152344
# trial 3 UCB_2 time: 0.7680349349975586
# trial 4 UCB_2 time: 0.7702100276947021
# trial 5 UCB_2 time: 0.833198070526123
# trial 6 UCB_2 time: 0.7719550132751465
# trial 7 UCB_2 time: 0.7710411548614502
# trial 8 UCB_2 time: 0.769071102142334
# trial 9 UCB_2 time: 0.8541362285614014
    UCBT_mean = UCBT.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_1_mean = EG_1.mean()
    EG_2_mean = EG_2.mean()
    EG_3_mean = EG_3.mean()
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.fill_between(T, EG_1.min(), EG_1.max(), color='#000000', alpha=0.2)
    
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')
    plt.fill_between(T, EG_2.min(), EG_2.max(), color='#000000', alpha=0.2)
    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    plt.fill_between(T, EG_3.min(), EG_3.max(), color='#000000', alpha=0.2)
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    plt.fill_between(T, TS.min(), TS.max(), color='#666666', alpha=0.2)
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.fill_between(T, UCB_1.min(), UCB_1.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.fill_between(T, UCB_2.min(), UCB_2.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.fill_between(T, UCBT.min(), UCBT.max(), color='#666600', alpha=0.2)

    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='#666600', alpha=0.2)

    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.fill_between(T, IDS_2.min(), IDS_2.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.fill_between(T, IDS_3.min(), IDS_3.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='#FF6666', alpha=0.2)
    
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned', 'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2', 'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Reward')
    plt.show()

# %%
title = 'Case 4: Seasonality'
draw_exp_graph(IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title)

# %%
draw_arm(IDS_1_df_arm, TS_df_arm, UCB_2_df_arm, EG_2_df_arm)

# %%
# import matplotlib.patches as mpatches
# def draw_exp_graph(IDS_1,IDST_1,UCB,UCBPI,TS, EG,sd=2):
#     IDS_1_mean = IDS_1.mean()
#     IDST_1_mean = IDST_1.mean()
#     UCB_mean = UCB.mean()
#     UCBPI_mean = UCBPI.mean()
#     TS_mean = TS.mean()
#     EG_mean = EG.mean()
    
#     T = np.arange(IDS_1.shape[1])
    
#     plt.figure(figsize=(30,20))
#     sns.set(font_scale=2)
    
#     for i in range(EG.shape[0]):
#         plt.plot(EG.iloc[i],alpha=0.2,color='pink')
#     plt.plot(EG_mean,alpha=1,color='pink')
#     plt.fill_between(T, EG.min(), EG.max(), color='pink', alpha=0.2)
    
#     for i in range(TS.shape[0]):
#         plt.plot(TS.iloc[i],alpha=0.2,color='purple')
#     plt.plot(TS_mean,alpha=1,color='purple')
#     plt.fill_between(T, TS.min(), TS.max(), color='purple', alpha=0.2)
    
#     for i in range(UCB.shape[0]):
#         plt.plot(UCB.iloc[i],alpha=0.2,color='gray')
#     plt.plot(UCB_mean,alpha=1,color='gray')
#     plt.fill_between(T, UCB.min(), UCB.max(), color='gray', alpha=0.2)
    
#     for i in range(UCBPI.shape[0]):
#         plt.plot(UCBPI.iloc[i],alpha=0.2,color='black')
#     plt.plot(UCBPI_mean,alpha=1,color='black')
#     plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='black', alpha=0.2)

#     for i in range(IDS_1.shape[0]):
#         plt.plot(IDS_1.iloc[i],alpha=0.2,color='red')
#     plt.plot(IDS_1_mean,alpha=1,color='red')
#     plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='red', alpha=0.2)
    
#     for i in range(IDST_1.shape[0]):
#         plt.plot(IDST_1.iloc[i],alpha=0.2,color='blue')
#     plt.plot(IDST_1_mean,alpha=1,color='blue')
#     plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='blue', alpha=0.2)
    
#     leg_UCB = mpatches.Patch(color='gray', label='UCB')
#     leg_UCBPI = mpatches.Patch(color='black', label='UCBPI')
#     leg_IDS_1 = mpatches.Patch(color='red', label='IDS_1')
#     leg_IDST_1 = mpatches.Patch(color='blue', label='IDST_1')
#     leg_TS = mpatches.Patch(color='purple', label='TS')
#     leg_EG = mpatches.Patch(color='pink', label='EG')
    
#     plt.legend(handles=[leg_UCB, leg_UCBPI, leg_IDS_1, leg_IDST_1, leg_TS, leg_EG], loc= 'lower right')
#     plt.show()

    
# draw_exp_graph(IDS_1_df,IDST_1_df,UCB_df,UCBPI_df,TS_df,EG_df,sd=1)

# %%
# sns.set(font_scale=1)
# print('IDS_1')
# plt.plot(IDS_1_arm)
# plt.show()
# print(IDS_1_re[-300:].mean())
# print('collection rounds:', IDS_1.collection_rounds)

# print('IDS_2')
# plt.plot(IDS_2_arm)
# plt.show()
# print(IDS_2_re[-300:].mean())
# print('collection rounds:', IDS_2.collection_rounds)

# print('IDS_3')
# plt.plot(IDS_3_arm)
# plt.show()
# print(IDS_3_re[-300:].mean())
# print('collection rounds:', IDS_3.collection_rounds)

# print('IDST_1')
# plt.plot(IDST_1_arm)
# plt.show()
# print(IDST_1_re[-300:].mean())
# print('collection rounds:', IDST_1.collection_rounds)

# print('UCB1')
# plt.plot(UCB1_arm)
# plt.show()
# print(UCB1_re[-300:].mean())

# print('UCBPI')
# plt.plot(UCBPI_arm)
# plt.show()
# print(UCBPI_re[-300:].mean())

# print('TS')
# plt.plot(TS_arm)
# plt.show()
# print(TS_re[-300:].mean())

# print('EG')
# plt.plot(EG_arm)
# plt.show()
# print(EG_re[-300:].mean())
