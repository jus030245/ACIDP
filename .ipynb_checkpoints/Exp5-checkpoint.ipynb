# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment5(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=1000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp5', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df, df2

# %%
#changeable parameters
np.random.seed(5566)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df, df2 = set_experiment5(price_list=price_list, segments=segments, update_freq =10, T=T)
sns.lineplot(data=exp_MAB_1.brownian_sequence)
# Out:
# The highest true optimal is 11
# The lowest true optimal is: 1
# time: 26.623296976089478
# <AxesSubplot:>

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 162
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 253
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 274
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 313
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 353
# Detected Sign: -1
# Reward change detected at time: 426
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 523
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 880
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 919
# Detected Sign: 1
# Reward change detected at time: 955
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1121
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1159
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1236
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1257
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1297
# Detected Sign: -1
# Reward change detected at time: 1338
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1502
# Detected Sign: -1
# Reward change detected at time: 1700
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 0 IDS_1 time: 245.59070324897766
# Reward change detected at time: 147
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 168
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 189
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 264
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 303
# Detected Sign: -1
# Reward change detected at time: 350
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 371
# Detected Sign: -1
# Reward change detected at time: 433
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 473
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 523
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 742
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 854
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 878
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 913
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 939
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1122
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1168
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1249
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1657
# Detected Sign: 1
# Reward change detected at time: 1699
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1726
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1776
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1973
# Detected Sign: 1
# Detector cooling
# trial 1 IDS_1 time: 307.07962107658386
# Reward change detected at time: 152
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 181
# Detected Sign: 1
# Reward change detected at time: 251
# Detected Sign: -1
# Reward change detected at time: 310
# Detected Sign: 1
# Reward change detected at time: 399
# Detected Sign: -1
# Reward change detected at time: 425
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 454
# Detected Sign: -1
# Reward change detected at time: 525
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 879
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 947
# Detected Sign: 1
# Reward change detected at time: 1054
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1123
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1241
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1700
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1731
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1775
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1817
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 2 IDS_1 time: 628.0466527938843
# Reward change detected at time: 102
# Detected Sign: -1
# Reward change detected at time: 181
# Detected Sign: 1
# Reward change detected at time: 254
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 309
# Detected Sign: 1
# Reward change detected at time: 358
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 399
# Detected Sign: -1
# Reward change detected at time: 453
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 524
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 740
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 878
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1053
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1082
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1242
# Detected Sign: -1
# Reward change detected at time: 1300
# Detected Sign: -1
# Reward change detected at time: 1682
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1703
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1775
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1796
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1819
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1844
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1912
# Detected Sign: -1
# Detector cooling
# Detector cooling
# trial 3 IDS_1 time: 278.5153260231018
# Reward change detected at time: 182
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 253
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 316
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 351
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 390
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 429
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time:
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1704
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1798
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1819
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1841
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1960
# Detected Sign: 1
# trial 8 IDST_1 time: 340.6731421947479
# Reward change detected at time: 185
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 254
# Detected Sign: -1
# Reward change detected at time: 528
# Detected Sign: 1
# Reward change detected at time: 746
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 881
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1052
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1187
# Detected Sign: 1
# Reward change detected at time: 1251
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1299
# Detected Sign: -1
# Reward change detected at time: 1503
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1687
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1711
# Detected Sign: 1
# Reward change detected at time: 1830
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1853
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1910
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1931
# Detected Sign: -1
# trial 9 IDST_1 time: 311.5860478878021

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 158
# Detected Sign: -1
# Reward change detected at time: 306
# Detected Sign: 1
# Reward change detected at time: 456
# Detected Sign: -1
# Reward change detected at time: 496
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 707
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 788
# Detected Sign: -1
# Reward change detected at time: 880
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 932
# Detected Sign: 1
# Reward change detected at time: 1053
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1120
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1239
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1501
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1682
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1704
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1821
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1847
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1978
# Detected Sign: 1
# trial 0 IDS_2 time: 227.97691106796265
# Reward change detected at time: 162
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 183
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 237
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 310
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 392
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 432
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 453
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 524
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 785
# Detected Sign: -1
# Reward change detected at time: 876
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 925
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 946
# Detected Sign: 1
# Reward change detected at time: 1124
# Detected Sign: -1
# Reward change detected at time: 1254
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1504
# Detected Sign: -1
# Reward change detected at time: 1700
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1727
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1819
# Detected Sign: -1
# Reward change detected at time: 1950
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1977
# Detected Sign: -1
# Detector cooling
# trial 1 IDS_2 time: 266.0780899524689
# Reward change detected at time: 185
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 271
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 360
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 404
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 442
# Detected Sign: 1
# Reward change detected at time: 516
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 878
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 904
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 935
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1123
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1258
# Detected Sign: -1
# Reward change detected at time: 1683
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1705
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1797
# Detected Sign: 1
# Reward change detected at time: 1819
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1861
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1913
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1935
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1956
# Detected Sign: -1
# Detector cooling
# trial 2 IDS_2 time: 256.7328510284424
# Reward change detected at time: 155
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 177
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 252
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 394
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 426
# Detected Sign: -1
# Detector cooling
# Reward change detected at time:
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1523
# Detected Sign: -1
# Reward change detected at time: 1648
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1821
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1843
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1948
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1976
# Detected Sign: 1
# trial 7 IDS_3 time: 197.59613418579102
# Reward change detected at time: 159
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 211
# Detected Sign: 1
# Reward change detected at time: 257
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 278
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 320
# Detected Sign: 1
# Reward change detected at time: 390
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 426
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 526
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 739
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 793
# Detected Sign: -1
# Reward change detected at time: 877
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 933
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1137
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1169
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1258
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1303
# Detected Sign: -1
# Reward change detected at time: 1502
# Detected Sign: -1
# Reward change detected at time: 1683
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1707
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1820
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1864
# Detected Sign: -1
# Reward change detected at time: 1943
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 8 IDS_3 time: 284.16297030448914
# Reward change detected at time: 166
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 187
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 360
# Detected Sign: -1
# Reward change detected at time: 453
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 528
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 743
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 858
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 879
# Detected Sign: -1
# Reward change detected at time: 931
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1053
# Detected Sign: -1
# Reward change detected at time: 1091
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1139
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1214
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1235
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1501
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1651
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1681
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1703
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1833
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1915
# Detected Sign: -1
# trial 9 IDS_3 time: 262.05298614501953

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=False, tuned=True)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.7381870746612549
# trial 1 UCB_1 time: 0.7258450984954834
# trial 2 UCB_1 time: 0.7360796928405762
# trial 3 UCB_1 time: 0.733950138092041
# trial 4 UCB_1 time: 0.7441589832305908
# trial 5 UCB_1 time: 0.7515530586242676
# trial 6 UCB_1 time: 0.7302289009094238
# trial 7 UCB_1 time: 0.7373380661010742
# trial 8 UCB_1 time: 0.7349729537963867
# trial 9 UCB_1 time: 0.7520871162414551
# trial 0 UCB_2 time: 0.7466332912445068
# trial 1 UCB_2 time: 0.733954668045044
# trial 2 UCB_2 time: 0.7489180564880371
# trial 3 UCB_2 time: 0.7601189613342285
# trial 4 UCB_2 time: 0.7293100357055664
# trial 5 UCB_2 time: 0.7263422012329102
# trial 6 UCB_2 time: 0.750633955001831
# trial 7 UCB_2 time: 0.7404742240905762
# trial 8 UCB_2 time: 0.7316269874572754
# trial 9 UCB_2 time: 0.7551591396331787
# trial 0 UCB-tuned time: 1.523360013961792
# trial 1 UCB-tuned time: 1.534224271774292
# trial 2 UCB-tuned time: 1.5398340225219727
# trial 3 UCB-tuned time: 1.5232629776000977
# trial 4 UCB-tuned time: 1.5709340572357178
# trial 5 UCB-tuned time: 1.5784177780151367
# trial 6 UCB-tuned time: 1.5230438709259033
# trial 7 UCB-tuned time: 1.5205509662628174
# trial 8 UCB-tuned time: 1.5916199684143066
# trial 9 UCB-tuned time: 1.5804247856140137
# trial 0 UCBPI time: 1.2652919292449951
# trial 1 UCBPI time: 1.0642900466918945
# trial 2 UCBPI time: 1.3410120010375977
# trial 3 UCBPI time: 1.3422038555145264
# trial 4 UCBPI time: 1.2063860893249512
# trial 5 UCBPI time: 1.2743198871612549
# trial 6 UCBPI time: 1.2862188816070557
# trial 7 UCBPI time: 1.313288927078247
# trial 8 UCBPI time: 1.2741100788116455
# trial 9 UCBPI time: 1.2589330673217773
# trial 0 TS time: 1.6073861122131348
# trial 1 TS time: 1.5357697010040283
# trial 2 TS time: 1.6763370037078857
# trial 3 TS time: 1.6490962505340576
# trial 4 TS time: 1.581230878829956
# trial 5 TS time: 1.5776588916778564
# trial 6 TS time: 1.6039180755615234
# trial 7 TS time: 1.568803071975708
# trial 8 TS time: 1.5129432678222656
# trial 9 TS time: 1.5870411396026611
# trial 0 EG 0.05 time: 0.14559698104858398
# trial 1 EG 0.05 time: 0.14420676231384277
# trial 2 EG 0.05 time: 0.1476879119873047
# trial 3 EG 0.05 time: 0.14290618896484375
# trial 4 EG 0.05 time: 0.14328813552856445
# trial 5 EG 0.05 time: 0.14927196502685547
# trial 6 EG 0.05 time: 0.14438986778259277
# trial 7 EG 0.05 time: 0.14377284049987793
# trial 8 EG 0.05 time: 0.14977002143859863
# trial 9 EG 0.05 time: 0.14220905303955078
# trial 0 EG 0.1 time: 0.14270281791687012
# trial 1 EG 0.1 time: 0.1477489471435547
# trial 2 EG 0.1 time: 0.14798474311828613
# trial 3 EG 0.1 time: 0.13973188400268555
# trial 4 EG 0.1 time: 0.150068998336792
# trial 5 EG 0.1 time: 0.14655590057373047
# trial 6 EG 0.1 time: 0.1493830680847168
# trial 7 EG 0.1 time: 0.14519214630126953
# trial 8 EG 0.1 time: 0.15442395210266113
# trial 9 EG 0.1 time: 0.14241290092468262
# trial 0 EG 0.15 time: 0.1388108730316162
# trial 1 EG 0.15 time: 0.1531977653503418
# trial 2 EG 0.15 time: 0.14554190635681152
# trial 3 EG 0.15 time: 0.13972711563110352
# trial 4 EG 0.15 time: 0.1379709243774414
# trial 5 EG 0.15 time: 0.15458464622497559
# trial 6 EG 0.15 time: 0.13953256607055664
# trial 7 EG 0.15 time: 0.13998699188232422
# trial 8 EG 0.15 time: 0.1390547752380371
# trial 9 EG 0.15 time: 0.13799214363098145

# %%
def draw_exp_graph(IDS_1, IDS_2, IDS_3, IDST_1, UCB_1, UCB_2, UCBT, UCBPI, TS, EG_1, EG_2, EG_3, title):
    
    IDS_1_mean = IDS_1.mean()
    IDS_2_mean = IDS_2.mean()
    IDS_3_mean = IDS_3.mean()
    IDST_1_mean = IDST_1.mean()
    UCB_1_mean = UCB_1.mean()
    UCB_2_mean =UCB_2.mean()
    UCBT_mean = UCBT.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_1_mean = EG_1.mean()
    EG_2_mean = EG_2.mean()
    EG_3_mean = EG_3.mean()
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.fill_between(T, EG_1.min(), EG_1.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')
    plt.fill_between(T, EG_2.min(), EG_2.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    plt.fill_between(T, EG_3.min(), EG_3.max(), color='#000000', alpha=0.1)
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    plt.fill_between(T, TS.min(), TS.max(), color='#666666', alpha=0.2)
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.fill_between(T, UCB_1.min(), UCB_1.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.fill_between(T, UCB_2.min(), UCB_2.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.fill_between(T, UCBT.min(), UCBT.max(), color='#666600', alpha=0.2)

    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='#666600', alpha=0.2)

    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.fill_between(T, IDS_2.min(), IDS_2.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.fill_between(T, IDS_3.min(), IDS_3.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='#FF6666', alpha=0.2)
    
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned', 'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2', 'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Reward')
    plt.show()

# %%
title = 'Case 5: volatility'
draw_exp_graph(IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title)

# %%
draw_arm(IDS_1_df_arm, TS_df_arm, UCB_2_df_arm, EG_2_df_arm)

# %%
def value_exp5(t, T=2000, size=10000):
    seg = np.random.choice(exp_MAB_1.seg_means.size, size, replace=True)
    shift = exp_MAB_1.brownian_sequence[t]
    value = exp_MAB_1.seg_means[seg] + np.random.normal(0, 0.1, size) + shift
    return value

def optimal_reward(T, size=10000):
    optimal_arm_per = np.zeros(T)
    optimal_reward_per = np.zeros(T)
    for t in range(T):
        optimal_arm = 0
        optimal_reward_t = 0
        for k, p in enumerate(price_list):
            expect_reward = sum(value_exp5(t, size=size) > p) * p / size * 10
            if expect_reward > optimal_reward_t:
                optimal_reward_t = expect_reward
                optimal_arm = k
        optimal_reward_per[t] = optimal_reward_t
        optimal_arm_per[t] = optimal_arm
    return optimal_arm_per, optimal_reward_per

# %%
optimal_arm_per, optimal_reward_per = optimal_reward(2000)

# %%
optimal_reward = pd.DataFrame(optimal_reward_per).T.cumsum(axis=1)
def get_low(optimal_reward, df):
    return (optimal_reward - df.max()).values[0]
def get_high(optimal_reward, df):
    return (optimal_reward - df.min()).values[0]

def draw_regret(optimal_reward, IDS_1, IDS_2, IDS_3, IDST_1, UCB_1, UCB_2, UCBT, UCBPI, TS, EG_1, EG_2, EG_3, title, bounds=True):
    
    IDS_1_mean = (optimal_reward - IDS_1.mean()).values[0]
    IDS_2_mean = (optimal_reward - IDS_2.mean()).values[0]
    IDS_3_mean = (optimal_reward - IDS_3.mean()).values[0]
    IDST_1_mean = (optimal_reward - IDST_1.mean()).values[0]
    UCB_1_mean = (optimal_reward - UCB_1.mean()).values[0]
    UCB_2_mean = (optimal_reward - UCB_2.mean()).values[0]
    UCBT_mean = (optimal_reward - UCBT.mean()).values[0]
    UCBPI_mean = (optimal_reward - UCBPI.mean()).values[0]
    TS_mean = (optimal_reward - TS.mean()).values[0]
    EG_1_mean = (optimal_reward - EG_1.mean()).values[0]
    EG_2_mean = (optimal_reward - EG_2.mean()).values[0]
    EG_3_mean = (optimal_reward - EG_3.mean()).values[0]
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')


    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')

    
    if bounds:
        plt.fill_between(T, get_low(optimal_reward, EG_1), get_high(optimal_reward, EG_1), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, EG_2), get_high(optimal_reward, EG_2), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, EG_3), get_high(optimal_reward, EG_3), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, TS), get_high(optimal_reward, TS), color='#666666', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, UCB_1), get_high(optimal_reward, UCB_1), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCB_2), get_high(optimal_reward, UCB_2), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCBT), get_high(optimal_reward, UCBT), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCBPI), get_high(optimal_reward, UCBPI), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_1), get_high(optimal_reward, IDS_1), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_2), get_high(optimal_reward, IDS_2), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_3), get_high(optimal_reward, IDS_3), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDST_1), get_high(optimal_reward, IDST_1), color='#FF6666', alpha=0.2)

        
        
        
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned',
                'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2',
                'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Regret')
    plt.show()
    
draw_regret(optimal_reward, IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title, bounds=True)

# %%
draw_regret(optimal_reward, IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title, bounds=False)

# %%
def draw_arm_withopt(IDS, TS, UCB, EG, optimal_arm):
    sns.set(font_scale=1.5, style='white')
    figure, axis = plt.subplots(2, 2, figsize=(20,12))

    trial = EG.shape[0]
    X = np.arange(EG.shape[1])
    for i in range(trial):
        axis[0, 0].scatter(x=X, y=IDS.iloc[i], alpha=0.1, s=10, color='#FF6666')
    axis[0, 0].plot(optimal_arm_per, color='r', linewidth=1, linestyle='--')
    axis[0, 0].set_ylim([-1, 20])
    axis[0, 0].set_ylabel('Pulled Arms')
    axis[0, 0].set_title('IDS')

    for i in range(trial):
        axis[0, 1].scatter(x=X, y=TS.iloc[i], alpha=0.1, s=10, color='#666666')
    axis[0, 1].plot(optimal_arm_per, color='r', linewidth=1, linestyle='--')
    axis[0, 1].set_ylim([-1, 20])
    axis[0, 1].set_ylabel('Pulled Arms')
    axis[0, 1].set_title('TS')

    for i in range(trial):
        axis[1, 0].scatter(x=X, y=UCB.iloc[i], alpha=0.1, s=10, color='#666600')
    axis[1, 0].plot(optimal_arm_per, color='r', linewidth=1, linestyle='--')
    axis[1, 0].set_ylim([-1, 20])
    axis[1, 0].set_ylabel('Pulled Arms')
    axis[1, 0].set_title('UCB')

    for i in range(trial):
        axis[1, 1].scatter(x=X, y=EG.iloc[i], alpha=0.1, s=10, color='#996633')
    axis[1, 1].plot(optimal_arm_per, color='r', linewidth=1, linestyle='--')
    axis[1, 1].set_ylim([-1, 20])
    axis[1, 1].set_ylabel('Pulled Arms')
    axis[1, 1].set_title('EG')

    figure.text(0.5, 0.05, 'Horizon')
    plt.show()
    
draw_arm_withopt(IDS_1_df_arm, TS_df_arm, UCB_2_df_arm, EG_2_df_arm, optimal_arm_per)
