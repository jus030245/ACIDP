# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment5(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=1000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp5', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df, df2

# %%
#changeable parameters
np.random.seed(5566)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 2
exp_MAB_1, df, df2 = set_experiment5(price_list=price_list, segments=segments, update_freq =10, T=T)
sns.lineplot(data=exp_MAB_1.brownian_sequence)
# Out:
# The highest true optimal is 28
# The lowest true optimal is: 4
# time: 65.27980184555054
# <AxesSubplot:>

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, eg_p=0.01,  window_width=100)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 261
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 285
# Detected Sign: -1
# Reward change detected at time: 361
# Detected Sign: -1
# Detector cooling
# eg triggered at  371
# arm
# 4.0     1.000000
# 10.0    0.903164
# 11.0    0.267626
# 12.0    0.754392
# 20.0    0.631934
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 401
# Detected Sign: -1
# Reward change detected at time: 521
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  555
# arm
# 4.0     1.000000
# 11.0    0.650301
# 12.0    0.779329
# 20.0    0.753339
# 28.0    0.033086
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 879
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 900
# Detected Sign: -1
# eg triggered at  912
# arm
# 4.0     0.000448
# 9.0     0.828532
# 11.0    0.343656
# 12.0    1.000000
# 20.0    0.613185
# 28.0    0.000605
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 943
# Detected Sign: 1
# eg triggered at  1013
# arm
# 4.0     1.000000
# 12.0    0.081172
# 13.0    0.412367
# 14.0    0.229514
# 15.0    0.422732
# 16.0    0.002828
# 20.0    0.054266
# 28.0    0.004399
# 36.0    0.031939
# 44.0    0.006562
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1127
# Detected Sign: -1
# Detector cooling
# eg triggered at  1173
# arm
# 4.0     1.000000
# 12.0    0.016097
# 13.0    0.213260
# 14.0    0.714447
# 15.0    0.831305
# 16.0    0.280378
# 20.0    0.762064
# 28.0    0.661714
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 1657
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1823
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1879
# arm
# 4.0     4.111776e-02
# 7.0     2.019385e-07
# 8.0     9.923835e-28
# 9.0     2.562748e-48
# 10.0    9.877848e-06
# 11.0    7.486506e-01
# 12.0    1.000000e+00
# 20.0    7.335915e-01
# 28.0    1.156763e-01
# 36.0    1.726357e-02
# 44.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1918
# Detected Sign: -1
# Detector cooling
# Detector cooling
# trial 0 IDS_1 time: 1349.1647610664368
# Reward change detected at time: 527
# Detected Sign: 1
# eg triggered at  780
# arm
# 4.0     5.484013e-03
# 8.0     1.000000e+00
# 12.0    9.441499e-02
# 13.0    2.866667e-02
# 14.0    2.147544e-01
# 15.0    2.466607e-02
# 16.0    3.271169e-01
# 17.0    8.267889e-11
# 18.0    6.038704e-02
# 19.0    3.098146e-04
# 20.0    5.266610e-01
# 22.0    1.565101e-20
# 23.0    6.214372e-71
# 24.0    8.085263e-06
# 25.0    7.602230e-71
# 28.0    3.756893e-01
# 36.0    1.000000e+00
# 44.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 878
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  892
# arm
# 4.0     0.009788
# 7.0     1.000000
# 8.0     0.528480
# 10.0    0.657758
# 12.0    1.000000
# 20.0    0.461510
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 1348
# Detected Sign: -1
# Detector cooling
# eg triggered at  1380
# arm
# 3.0     0.688869
# 4.0     0.714691
# 5.0     0.317131
# 7.0     1.000000
# 8.0     1.000000
# 12.0    1.000000
# 20.0    1.000000
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 1503
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1540
# arm
# 2.0     0.311412
# 3.0     0.664818
# 4.0     0.767343
# 5.0     0.649663
# 12.0    1.000000
# 13.0    1.000000
# 20.0    1.000000
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 1681
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1702
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1723
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1773
# Detected Sign: -1
# Reward change detected at time: 1818
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1839
# arm
# 3.0     1.000000
# 4.0     0.326909
# 12.0    0.001761
# 20.0    0.006628
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 1 IDS_1 time: 1019.4178440570831

# %%
#IDST_1
IDST_1_df = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDST_1 = IDS_theta_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, eg_p=0.01, window_width=100)
    IDST_1_sum, IDST_1_pt, IDST_1_re, IDST_1_arm, IDST_1_post = IDST_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDST_1 time:',end-start)
    IDST_1_df = IDST_1_df.append([np.cumsum(IDST_1_re)])
# Out:
# Reward change detected at time: 190
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 252
# Detected Sign: -1
# Detector cooling
# eg triggered at  308
# arm
# 4.0     1.000000
# 10.0    0.526187
# 11.0    0.754221
# 12.0    0.783864
# 13.0    0.671966
# 14.0    0.614761
# 15.0    0.010040
# 16.0    0.013691
# 20.0    0.003852
# 28.0    0.044502
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 452
# Detected Sign: 1
# eg triggered at  468
# arm
# 4.0     0.023190
# 12.0    0.528385
# 14.0    0.277206
# 20.0    1.000000
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 516
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  604
# arm
# 4.0     1.000000e+00
# 11.0    1.939881e-23
# 12.0    1.155005e-03
# 13.0    6.210479e-01
# 14.0    9.182122e-01
# 20.0    2.169618e-01
# 28.0    4.200459e-01
# 36.0    1.000000e+00
# 44.0    5.500158e-03
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 875
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 900
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  906
# arm
# 4.0     0.734655
# 10.0    0.340753
# 11.0    0.261859
# 12.0    0.744593
# 20.0    0.182660
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 941
# Detected Sign: 1
# Detector cooling
# eg triggered at  1082
# arm
# 4.0     1.000000
# 11.0    0.003035
# 12.0    0.087340
# 13.0    0.079773
# 14.0    0.000105
# 15.0    0.737722
# 16.0    0.357796
# 17.0    0.268457
# 18.0    0.930697
# 19.0    0.639271
# 20.0    0.620786
# 21.0    1.000000
# 22.0    0.012915
# 28.0    0.337644
# 36.0    0.531569
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1120
# Detected Sign: -1
# eg triggered at  1250
# arm
# 4.0     1.000000
# 11.0    1.000000
# 12.0    0.000004
# 13.0    0.394420
# 14.0    0.225106
# 15.0    0.054392
# 16.0    0.499832
# 20.0    0.350362
# 28.0    1.000000
# 36.0    0.237741
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1307
# Detected Sign: -1
# Detector cooling
# eg triggered at  1384
# arm
# 4.0     1.959767e-01
# 5.0     1.895366e-01
# 6.0     4.044763e-02
# 7.0     4.318360e-02
# 8.0     2.940658e-04
# 9.0     3.681433e-03
# 10.0    5.361448e-19
# 11.0    1.592874e-23
# 12.0    8.041747e-29
# 13.0    1.481535e-38
# 20.0    1.000000e+00
# 28.0    1.000000e+00
# 36.0    1.000000e+00
# 44.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1683
# Detected Sign: -1
# Reward change detected at time: 1779
# Detected Sign: -1
# Reward change detected at time: 1817
# Detected Sign: -1
# Reward change detected at time: 1920
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1941
# arm
# 4.0     0.470246
# 6.0     0.356517
# 8.0     0.061025
# 9.0     1.000000
# 10.0    0.855074
# 11.0    0.081805
# 12.0    0.420695
# 20.0    0.204194
# 28.0    0.000463
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 0 IDST_1 time: 95795.25266695023
# Reward change detected at time: 252
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  353
# arm
# 4.0     1.313904e-04
# 9.0     7.199175e-04
# 10.0    1.292398e-32
# 11.0    2.718288e-01
# 12.0    9.095935e-01
# 13.0    9.679357e-03
# 20.0    1.000000e+00
# 28.0    1.000000e+00
# 36.0    1.000000e+00
# 44.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 384
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  446
# arm
# 4.0     0.010214
# 10.0    0.508505
# 11.0    0.517807
# 12.0    0.202472
# 20.0    0.132816
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 519
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  709
# arm
# 4.0      1.000000e+00
# 11.0     1.543112e-61
# 12.0    3.691082e-100
# 13.0     1.907105e-21
# 14.0     4.964699e-07
# 15.0     3.667589e-55
# 17.0     1.000000e+00
# 18.0     1.000000e+00
# 19.0     4.759094e-01
# 20.0     8.154366e-01
# 21.0     2.984319e-05
# 22.0     1.149814e-04
# 28.0     3.395982e-01
# 36.0     1.948260e-01
# 44.0     1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 877
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 940
# Detected Sign: 1
# eg triggered at  1123
# arm
# 4.0     1.000000e+00
# 12.0    1.000000e+00
# 13.0    2.780194e-04
# 14.0    2.789499e-02
# 15.0    8.414716e-03
# 16.0    4.356238e-01
# 17.0    3.844241e-01
# 18.0    7.427480e-03
# 19.0    1.565771e-06
# 20.0    3.276291e-16
# 28.0    1.000000e+00
# 36.0    1.000000e+00
# 44.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1679
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1687
# arm
# 4.0     0.274663
# 5.0     0.380810
# 7.0     0.345823
# 12.0    1.000000
# 20.0    1.000000
# 28.0    1.000000
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# Reward change detected at time: 1703
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1734
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1777
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1816
# Detected Sign: -1
# Reward change detected at time: 1860
# Detected Sign: 1
# eg triggered at  1891
# arm
# 4.0     1.000000
# 7.0     0.382167
# 8.0     1.000000
# 11.0    1.000000
# 12.0    0.879000
# 13.0    0.374042
# 20.0    1.000000
# 28.0    0.616600
# 36.0    1.000000
# 44.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant
# trial 1 IDST_1 time: 1958.5207481384277

# %%
# UCB1
UCB_df = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB time:',end-start)
    UCB_df = UCB_df.append([np.cumsum(UCB1_re)])
    
# UCBPI family
UCBPI_df = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=4, bias=0, UCB1=False)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    
# TS
TS_df = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])

# EG
EG_df = pd.DataFrame()
EG_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG time:',end-start)
    EG_df = EG_df.append([np.cumsum(EG_re)])
# Out:
# trial 0 UCB time: 1.3829669952392578
# trial 1 UCB time: 1.3705029487609863
# trial 0 UCBPI time: 1.3650898933410645
# trial 1 UCBPI time: 1.3652071952819824
# trial 0 TS time: 4.849042892456055
# trial 1 TS time: 4.812757968902588
# trial 0 EG time: 0.13785386085510254
# trial 1 EG time: 0.1364741325378418

# %%
import matplotlib.patches as mpatches
def draw_exp_graph(IDS_1,IDST_1,UCB,UCBPI,TS, EG,sd=2):
    IDS_1_mean = IDS_1.mean()
    IDST_1_mean = IDST_1.mean()
    UCB_mean = UCB.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_mean = EG.mean()
    
    T = np.arange(IDS_1.shape[1])
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2)
    
    for i in range(EG.shape[0]):
        plt.plot(EG.iloc[i],alpha=0.2,color='pink')
    plt.plot(EG_mean,alpha=1,color='pink')
    plt.fill_between(T, EG.min(), EG.max(), color='pink', alpha=0.2)
    
    for i in range(TS.shape[0]):
        plt.plot(TS.iloc[i],alpha=0.2,color='purple')
    plt.plot(TS_mean,alpha=1,color='purple')
    plt.fill_between(T, TS.min(), TS.max(), color='purple', alpha=0.2)
    
    for i in range(UCB.shape[0]):
        plt.plot(UCB.iloc[i],alpha=0.2,color='gray')
    plt.plot(UCB_mean,alpha=1,color='gray')
    plt.fill_between(T, UCB.min(), UCB.max(), color='gray', alpha=0.2)
    
    for i in range(UCBPI.shape[0]):
        plt.plot(UCBPI.iloc[i],alpha=0.2,color='black')
    plt.plot(UCBPI_mean,alpha=1,color='black')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='black', alpha=0.2)

    for i in range(IDS_1.shape[0]):
        plt.plot(IDS_1.iloc[i],alpha=0.2,color='red')
    plt.plot(IDS_1_mean,alpha=1,color='red')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='red', alpha=0.2)
    
    for i in range(IDST_1.shape[0]):
        plt.plot(IDST_1.iloc[i],alpha=0.2,color='blue')
    plt.plot(IDST_1_mean,alpha=1,color='blue')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='blue', alpha=0.2)
    
    leg_UCB = mpatches.Patch(color='gray', label='UCB')
    leg_UCBPI = mpatches.Patch(color='black', label='UCBPI')
    leg_IDS_1 = mpatches.Patch(color='red', label='IDS_1')
    leg_IDST_1 = mpatches.Patch(color='blue', label='IDST_1')
    leg_TS = mpatches.Patch(color='purple', label='TS')
    leg_EG = mpatches.Patch(color='pink', label='EG')
    
    plt.legend(handles=[leg_UCB, leg_UCBPI, leg_IDS_1, leg_IDST_1, leg_TS, leg_EG], loc= 'lower right')
    plt.show()

    
draw_exp_graph(IDS_1_df,IDST_1_df,UCB_df,UCBPI_df,TS_df,EG_df,sd=1)

# %%
sns.set(font_scale=1)
print('IDS_1')
plt.plot(IDS_1_arm)
plt.show()
print(IDS_1_re[-300:].mean())
print('collection rounds:', IDS_1.collection_rounds)

print('IDST_1')
plt.plot(IDST_1_arm)
plt.show()
print(IDST_1_re[-300:].mean())
print('collection rounds:', IDST_1.collection_rounds)

print('UCB1')
plt.plot(UCB1_arm)
plt.show()
print(UCB1_re[-300:].mean())

print('UCBPI')
plt.plot(UCBPI_arm)
plt.show()
print(UCBPI_re[-300:].mean())

print('TS')
plt.plot(TS_arm)
plt.show()
print(UCBPI_re[-300:].mean())

print('EG')
plt.plot(EG_arm)
plt.show()
print(UCBPI_re[-300:].mean())
# Out:
# IDS_1
# 1.0662510204081632
# collection rounds: 125
# IDST_1
# 1.136695918367347
# collection rounds: 130
# UCB1
# 1.1085741496598642
# UCBPI
# 1.0561149659863944
# TS
# 1.0561149659863944
# EG
# 1.0561149659863944
