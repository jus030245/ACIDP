# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment5(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=1000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp5', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df, df2

# %%
#changeable parameters
np.random.seed(5566)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df, df2 = set_experiment5(price_list=price_list, segments=segments, update_freq =10, T=T)
sns.lineplot(data=exp_MAB_1.brownian_sequence)
# Out:
# The highest true optimal is 11
# The lowest true optimal is: 1
# time: 31.845233917236328
# <AxesSubplot:>

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 162
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 253
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 274
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 313
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 353
# Detected Sign: -1
# Reward change detected at time: 426
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 523
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 880
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 919
# Detected Sign: 1
# Reward change detected at time: 955
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1121
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1159
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1236
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1257
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1297
# Detected Sign: -1
# Reward change detected at time: 1338
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1502
# Detected Sign: -1
# Reward change detected at time: 1700
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 0 IDS_1 time: 299.26650524139404
# Reward change detected at time: 178
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 201
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 256
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 277
# Detected Sign: -1
# Reward change detected at time: 312
# Detected Sign: 1
# Reward change detected at time: 388
# Detected Sign: -1
# Reward change detected at time: 469
# Detected Sign: -1
# Reward change detected at time: 533
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 554
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 876
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 943
# Detected Sign: 1
# Reward change detected at time: 1053
# Detected Sign: -1
# Reward change detected at time: 1123
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1187
# Detected Sign: 1
# Reward change detected at time: 1254
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1299
# Detected Sign: -1
# Reward change detected at time: 1685
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1706
# Detected Sign: -1
# Reward change detected at time: 1820
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1841
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1973
# Detected Sign: 1
# trial 1 IDS_1 time: 341.2499670982361
# Reward change detected at time: 164
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 185
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 257
# Detected Sign: -1
# Reward change detected at time: 391
# Detected Sign: -1
# Reward change detected at time: 525
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 640
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 738
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 877
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 911
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 942
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1123
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1211
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1241
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1262
# Detected Sign: -1
# Reward change detected at time: 1645
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1686
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1707
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1728
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1768
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1793
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1826
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1943
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1975
# Detected Sign: 1
# trial 2 IDS_1 time: 369.56290102005005
# Reward change detected at time: 151
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 251
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 355
# Detected Sign: -1
# Reward change detected at time: 611
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 737
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 788
# Detected Sign: -1
# Reward change detected at time: 873
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 929
# Detected Sign: 1
# Reward change detected at time: 1050
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1092
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1252
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1499
# Detected Sign: -1
# Reward change detected at time: 1646
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1679
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1700
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1725
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1817
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1975
# Detected Sign: 1
# Detector cooling
# trial 3 IDS_1 time: 292.28565788269043
# Reward change detected at time: 107
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 146
# Detected Sign: 1
# Reward change detected at time: 252
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 354
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 422
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 521
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 921
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1254
# Detected Sign: -1
# Reward change detected at time: 1696
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1721
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1237
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1261
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1484
# Detected Sign: -1
# Reward change detected at time: 1802
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1826
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# trial 8 IDST_1 time: 405.97843194007874
# Reward change detected at time: 177
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 198
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 337
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 506
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 718
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 859
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1034
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1102
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1219
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1672
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1693
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1777
# Detected Sign: 1
# trial 9 IDST_1 time: 279.4291989803314

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=0,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 159
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 180
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 201
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 290
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 329
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 369
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 411
# Detected Sign: 1
# Reward change detected at time: 505
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 526
# Detected Sign: 1
# Reward change detected at time: 625
# Detected Sign: 1
# Reward change detected at time: 724
# Detected Sign: -1
# Reward change detected at time: 857
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 924
# Detected Sign: 1
# Reward change detected at time: 1104
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1222
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1482
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1679
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1700
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1721
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1772
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1902
# Detected Sign: -1
# trial 0 IDS_2 time: 296.97011280059814
# Reward change detected at time: 162
# Detected Sign: 1
# Reward change detected at time: 232
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 289
# Detected Sign: 1
# Reward change detected at time: 372
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 414
# Detected Sign: 1
# Reward change detected at time: 502
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 766
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 857
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 892
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 918
# Detected Sign: 1
# Reward change detected at time: 1117
# Detected Sign: -1
# Reward change detected at time: 1138
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1159
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1215
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1236
# Detected Sign: -1
# Reward change detected at time: 1481
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1679
# Detected Sign: -1
# Reward change detected at time: 1799
# Detected Sign: -1
# Reward change detected at time: 1847
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1982
# Detected Sign: 1
# Detector cooling
# trial 1 IDS_2 time: 278.5866837501526
# Reward change detected at time: 167
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 188
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 233
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 337
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 370
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 433
# Detected Sign: -1
# Reward change detected at time: 481
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 502
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 837
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 858
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 908
# Detected Sign: 1
# Reward change detected at time: 1100
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1143
# Detected Sign: 1
# Reward change detected at time: 1216
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1243
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1795
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1816
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1933
# Detected Sign: 1
# trial 2 IDS_2 time: 248.19941091537476
# Reward change detected at time: 165
# Detected Sign: 1
# Reward change detected at time: 230
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 284
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 325
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 367
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 499
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 760
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 856
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 937
# Detected Sign: 1
# Reward change detected at time: 1030
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1072
# Detected Sign: -1
# Reward change detected at time: 1097
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1216
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1238
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1478
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1759
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1795
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1825
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1929
# Detected Sign: 1
# Reward change detected at time: 1980
# Detected Sign: -1
# trial 3 IDS_2 time: 265.3974151611328
# Reward change detected at time: 160
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 230
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 288
# Detected Sign: 1
# Reward change detected at time: 327
# Detected Sign: -1
# Reward change detected at time: 370
# Detected Sign: -1
# Reward change detected at time: 460
# Detected Sign: -1
# Reward change detected at time: 497
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time:
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1994
# Detected Sign: -1
# Detector cooling
# trial 9 IDS_3 time: 260.4842801094055

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=False, tuned=True)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.7399351596832275
# trial 1 UCB_1 time: 0.7226409912109375
# trial 2 UCB_1 time: 0.7128660678863525
# trial 3 UCB_1 time: 0.7279460430145264
# trial 4 UCB_1 time: 0.7220602035522461
# trial 5 UCB_1 time: 0.7364590167999268
# trial 6 UCB_1 time: 0.7273569107055664
# trial 7 UCB_1 time: 0.7304408550262451
# trial 8 UCB_1 time: 0.7149879932403564
# trial 9 UCB_1 time: 0.72776198387146
# trial 0 UCB_2 time: 0.7459557056427002
# trial 1 UCB_2 time: 0.7539529800415039
# trial 2 UCB_2 time: 0.7377910614013672
# trial 3 UCB_2 time: 0.7262740135192871
# trial 4 UCB_2 time: 0.7233948707580566
# trial 5 UCB_2 time: 0.7154388427734375
# trial 6 UCB_2 time: 0.7333509922027588
# trial 7 UCB_2 time: 0.7199759483337402
# trial 8 UCB_2 time: 0.7258579730987549
# trial 9 UCB_2 time: 0.7456717491149902
    UCB_2_mean =UCB_2.mean()
    UCBT_mean = UCBT.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_1_mean = EG_1.mean()
    EG_2_mean = EG_2.mean()
    EG_3_mean = EG_3.mean()
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.fill_between(T, EG_1.min(), EG_1.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')
    plt.fill_between(T, EG_2.min(), EG_2.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    plt.fill_between(T, EG_3.min(), EG_3.max(), color='#000000', alpha=0.1)
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    plt.fill_between(T, TS.min(), TS.max(), color='#666666', alpha=0.2)
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.fill_between(T, UCB_1.min(), UCB_1.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.fill_between(T, UCB_2.min(), UCB_2.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.fill_between(T, UCBT.min(), UCBT.max(), color='#666600', alpha=0.2)

    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='#666600', alpha=0.2)

    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.fill_between(T, IDS_2.min(), IDS_2.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.fill_between(T, IDS_3.min(), IDS_3.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='#FF6666', alpha=0.2)
    
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned', 'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2', 'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Reward')
    plt.show()

# %%
title = 'Case 5: volatility'
draw_exp_graph(IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title)

# %%
draw_arm(IDS_1_df_arm, TS_df_arm, UCB_2_df_arm, EG_2_df_arm)

# %%
import matplotlib.patches as mpatches
def draw_exp_graph(IDS_1,IDST_1,UCB,UCBPI,TS, EG,sd=2):
    IDS_1_mean = IDS_1.mean()
    IDST_1_mean = IDST_1.mean()
    UCB_mean = UCB.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_mean = EG.mean()
    
    T = np.arange(IDS_1.shape[1])
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2)
    
    for i in range(EG.shape[0]):
        plt.plot(EG.iloc[i],alpha=0.2,color='pink')
    plt.plot(EG_mean,alpha=1,color='pink')
    plt.fill_between(T, EG.min(), EG.max(), color='pink', alpha=0.2)
    
    for i in range(TS.shape[0]):
        plt.plot(TS.iloc[i],alpha=0.2,color='purple')
    plt.plot(TS_mean,alpha=1,color='purple')
    plt.fill_between(T, TS.min(), TS.max(), color='purple', alpha=0.2)
    
    for i in range(UCB.shape[0]):
        plt.plot(UCB.iloc[i],alpha=0.2,color='gray')
    plt.plot(UCB_mean,alpha=1,color='gray')
    plt.fill_between(T, UCB.min(), UCB.max(), color='gray', alpha=0.2)
    
    for i in range(UCBPI.shape[0]):
        plt.plot(UCBPI.iloc[i],alpha=0.2,color='black')
    plt.plot(UCBPI_mean,alpha=1,color='black')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='black', alpha=0.2)

    for i in range(IDS_1.shape[0]):
        plt.plot(IDS_1.iloc[i],alpha=0.2,color='red')
    plt.plot(IDS_1_mean,alpha=1,color='red')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='red', alpha=0.2)
    
    for i in range(IDST_1.shape[0]):
        plt.plot(IDST_1.iloc[i],alpha=0.2,color='blue')
    plt.plot(IDST_1_mean,alpha=1,color='blue')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='blue', alpha=0.2)
    
    leg_UCB = mpatches.Patch(color='gray', label='UCB')
    leg_UCBPI = mpatches.Patch(color='black', label='UCBPI')
    leg_IDS_1 = mpatches.Patch(color='red', label='IDS_1')
    leg_IDST_1 = mpatches.Patch(color='blue', label='IDST_1')
    leg_TS = mpatches.Patch(color='purple', label='TS')
    leg_EG = mpatches.Patch(color='pink', label='EG')
    
    plt.legend(handles=[leg_UCB, leg_UCBPI, leg_IDS_1, leg_IDST_1, leg_TS, leg_EG], loc= 'lower right')
    plt.show()

    
draw_exp_graph(IDS_1_df,IDST_1_df,UCB_df,UCBPI_df,TS_df,EG_df,sd=1)

# %%
sns.set(font_scale=1)
print('IDS_1')
plt.plot(IDS_1_arm)
plt.show()
print(IDS_1_re[-300:].mean())
print('collection rounds:', IDS_1.collection_rounds)

print('IDS_2')
plt.plot(IDS_2_arm)
plt.show()
print(IDS_2_re[-300:].mean())
print('collection rounds:', IDS_2.collection_rounds)

print('IDS_3')
plt.plot(IDS_3_arm)
plt.show()
print(IDS_3_re[-300:].mean())
print('collection rounds:', IDS_3.collection_rounds)

print('IDST_1')
plt.plot(IDST_1_arm)
plt.show()
print(IDST_1_re[-300:].mean())
print('collection rounds:', IDST_1.collection_rounds)

print('UCB1')
plt.plot(UCB1_arm)
plt.show()
print(UCB1_re[-300:].mean())

print('UCBPI')
plt.plot(UCBPI_arm)
plt.show()
print(UCBPI_re[-300:].mean())

print('TS')
plt.plot(TS_arm)
plt.show()
print(TS_re[-300:].mean())

print('EG')
plt.plot(EG_arm)
plt.show()
print(EG_re[-300:].mean())
