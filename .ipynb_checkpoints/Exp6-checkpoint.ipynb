# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment6(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=2000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp6', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df1, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df1, df2

# %%
#changeable parameters
np.random.seed(7777)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df1, df2 = set_experiment6(price_list=price_list, segments=segments, update_freq =10, T=T)
sns.kdeplot(exp_MAB_1.seg_means, color='orange')
sns.kdeplot(exp_MAB_1.seg_means_2)
# Out:
# The true optimal arm in first 1000 rounds is: 5
# The true optimal arm in the rest is: 12
# time: 24.83864688873291
# <AxesSubplot:ylabel='Density'>

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    exp_MAB_1.reset_t()
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 327
# Detected Sign: -1
# eg triggered at  370
# arm
# 1.0     1.000000
# 4.0     0.665598
# 5.0     0.505500
# 7.0     0.337659
# 8.0     0.300416
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  528
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.014324
# 7.0     0.048331
# 11.0    0.168022
# 14.0    0.011428
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 984
# Detected Sign: -1
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1059
# arm
# 1.0     1.000000
# 4.0     0.348974
# 5.0     0.679388
# 6.0     0.375888
# 7.0     0.440396
# 11.0    0.500604
# 14.0    0.001075
# 17.0    0.063501
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1468
# Detected Sign: 1
# eg triggered at  1505
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     1.000000
# 10.0    0.345201
# 11.0    0.055241
# 14.0    0.762546
# 17.0    0.468079
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1653
# arm
# 1.0     0.008738
# 4.0     1.000000
# 7.0     0.633054
# 10.0    0.461912
# 11.0    0.136756
# 14.0    1.000000
# 17.0    0.439493
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 0 IDS_1 time: 96.1160798072815
# Reward change detected at time: 381
# Detected Sign: 1
# eg triggered at  496
# arm
# 1.0     0.594709
# 4.0     0.019640
# 5.0     0.630851
# 6.0     0.203223
# 7.0     0.211652
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  547
# arm
# 1.0     1.000000
# 4.0     0.510793
# 6.0     0.850472
# 7.0     0.101002
# 11.0    0.232504
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 642
# Detected Sign: -1
# eg triggered at  657
# arm
# 1.0     0.601073
# 4.0     1.000000
# 6.0     0.305383
# 7.0     0.210378
# 11.0    0.614336
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 969
# Detected Sign: -1
# Detector cooling
# eg triggered at  987
# arm
# 1.0     1.000000
# 4.0     0.810451
# 5.0     0.694908
# 6.0     0.010893
# 7.0     0.750286
# 11.0    0.613147
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# arm
# 5.0     2.245440e-28
# 6.0     4.323751e-03
# 7.0     1.000000e+00
# 8.0     7.506293e-01
# 9.0     2.274562e-01
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1969
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1977
# arm
# 1.0     0.025327
# 4.0     0.071482
# 7.0     0.431969
# 11.0    1.000000
# 14.0    0.318474
# 17.0    0.736321
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 1 IDS_1 time: 108.32265758514404
# Reward change detected at time: 460
# Detected Sign: -1
# Detector cooling
# eg triggered at  491
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     1.000000
# 6.0     0.663702
# 7.0     0.749289
# 11.0    0.614234
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  503
# arm
# 1.0     0.351725
# 4.0     0.300070
# 5.0     0.425581
# 7.0     0.749288
# 11.0    0.009291
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 906
# Detected Sign: -1
# eg triggered at  911
# arm
# 1.0     1.000000
# 4.0     0.071708
# 5.0     0.038358
# 6.0     0.429143
# 7.0     0.541544
# 11.0    0.613191
# 14.0    0.054632
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: 1
# eg triggered at  1039
# arm
# 1.0     1.000000
# 4.0     0.000036
# 6.0     1.000000
# 7.0     0.046519
# 8.0     0.434901
# 11.0    1.000000
# 14.0    0.672277
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDS_1 time: 81.18803811073303
# Reward change detected at time: 272
# Detected Sign: 1
# eg triggered at  376
# arm
# 1.0     0.615132
# 4.0     0.335272
# 5.0     0.027197
# 6.0     0.439005
# 7.0     0.327258
# 11.0    0.604913
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  403
# arm
# 1.0     1.000000
# 4.0     0.101702
# 5.0     0.002274
# 7.0     0.733192
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1003
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1024
# Detected Sign: 1
# eg triggered at  1045
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.225643
# 11.0    0.038427
# 14.0    0.005186
# 17.0    0.001376
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1848
# Detected Sign: -1
# eg triggered at  1860
# arm
# 1.0     1.000000
# 4.0     0.399583
# 7.0     0.226588
# 11.0    0.111889
# 14.0    1.000000
# 17.0    0.304741
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1915
# arm
# 1.0     1.000000
# 4.0     0.390323
# 7.0     0.015275
# 11.0    1.000000
# 14.0    1.000000
# 17.0    0.052997
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 3 IDS_1 time: 119.44452118873596
# Reward change detected at time: 223
# Detected Sign: 1
# eg triggered at  278
# arm
# 1.0     1.000000
# 4.0     0.003557
# 5.0     0.399045
# 7.0     1.000000
# 8.0     1.000000
# 11.0    0.496546
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1044
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.001978
# 6.0     0.807276
# 7.0     0.138869
# 11.0    0.014896
# 14.0    0.000222
# 17.0    0.000004
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1386
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1415
# arm
# 1.0     1.000000
# 4.0     0.613544
# 7.0     0.424902
# 11.0    0.163963
# 12.0    0.811905
# 14.0    0.539168
# 17.0    0.417623
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1434
# arm
# 1.0     0.002382
# 4.0     1.000000
# 7.0     0.425209
# 11.0    0.512939
# 12.0    0.130527
# 14.0    0.335782
# 17.0    0.251474
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 4 IDS_1 time: 133.730375289917
# trial 5 IDS_1 time: 6.851430892944336
# Reward change detected at time: 319
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  409
# arm
# 1.0     1.000000
# 4.0     0.005715
# 5.0     0.357726
# 6.0     0.015370
# 7.0     0.529994
# 11.0    0.612643
# 14.0    0.031405
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 954
# Detected Sign: 1
# eg triggered at  979
# arm
# 1.0     0.326024
# 4.0     0.491743
# 5.0     0.221432
# 6.0     0.544169
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1007
# Detected Sign: -1
# eg triggered at  1057
# arm
# 1.0     1.000000
# 4.0     0.146151
# 5.0     0.401891
# 6.0     0.010223
# 7.0     0.458379
# 8.0     0.934262
# 11.0    0.207527
# 14.0    0.023765
# 17.0    0.004833
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 6 IDS_1 time: 109.81598424911499
# Reward change detected at time: 404
# Detected Sign: -1
# Detector cooling
# eg triggered at  427
# arm
# 1.0     0.012489
# 4.0     0.188891
# 5.0     0.726874
# 6.0     1.000000
# 7.0     0.739332
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 704
# Detected Sign: -1
# eg triggered at  704
# arm
# 1.0     0.623634
# 4.0     0.017958
# 5.0     0.757487
# 7.0     0.751545
# 11.0    0.377885
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  751
# arm
# 1.0     1.000000
# 4.0     0.186175
# 5.0     0.177163
# 7.0     1.000000
# 11.0    0.055403
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1009
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1069
# arm
# 1.0     0.000019
# 4.0     0.435032
# 5.0     0.630524
# 6.0     0.035768
# 7.0     1.000000
# 11.0    0.000230
# 14.0    0.054406
# 17.0    0.000173
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 7 IDS_1 time: 80.12638592720032
# Reward change detected at time: 843
# Detected Sign: -1
# eg triggered at  879
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.755834
# 6.0     1.000000
# 7.0     0.733322
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1030
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1044
# arm
# 1.0     1.000000
# 4.0     0.009085
# 5.0     0.507113
# 6.0     1.000000
# 7.0     0.859957
# 11.0    0.000046
# 14.0    0.017408
# 17.0    0.002554
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 8 IDS_1 time: 76.72352719306946
# Reward change detected at time: 1001
# Detected Sign: -1
# Detector cooling
# eg triggered at  1034
# arm
# 1.0     5.480938e-03
# 4.0     2.892044e-05
# 6.0     6.800234e-02
# 7.0     4.453703e-01
# 8.0     1.195635e-01
# 9.0     5.141781e-02
# 11.0    3.055034e-01
# 14.0    7.286435e-02
# 17.0    3.158179e-19
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1083
# Detected Sign: -1
# Detector cooling
# eg triggered at  1134
# arm
# 1.0     0.000430
# 4.0     1.000000
# 7.0     0.421362
# 9.0     1.000000
# 10.0    0.874347
# 11.0    0.750397
# 14.0    0.750404
# 17.0    0.669493
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1871
# Detected Sign: -1
# eg triggered at  1913
# arm
# 1.0     1.000000
# 4.0     0.200114
# 7.0     0.698452
# 11.0    0.185150
# 13.0    0.356125
# 14.0    0.345273
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1989
# arm
# 1.0     0.000641
# 4.0     1.000000
# 7.0     0.232128
# 11.0    0.512533
# 13.0    0.118664
# 14.0    1.000000
# 17.0    0.594594
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDS_1 time: 124.87090396881104

# %%
#IDST_1
IDST_1_df = pd.DataFrame()
IDST_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDST_1 = IDS_theta_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDST_1_sum, IDST_1_pt, IDST_1_re, IDST_1_arm, IDST_1_post = IDST_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDST_1 time:',end-start)
    exp_MAB_1.reset_t()
    IDST_1_df = IDST_1_df.append([np.cumsum(IDST_1_re)])
    IDST_1_df_arm = IDST_1_df_arm.append([IDST_1_arm])
# Out:
# Reward change detected at time: 442
# Detected Sign: -1
# eg triggered at  442
# arm
# 1.0     0.377522
# 4.0     0.739242
# 6.0     0.111138
# 7.0     0.536519
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  494
# arm
# 1.0     1.000000
# 4.0     0.153318
# 7.0     1.000000
# 11.0    0.613339
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 728
# Detected Sign: -1
# eg triggered at  756
# arm
# 1.0     1.000000
# 4.0     0.097358
# 5.0     0.658037
# 7.0     0.087302
# 11.0    0.613271
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  888
# arm
# 1.0     1.000000
# 4.0     0.455382
# 5.0     0.000795
# 7.0     0.203498
# 11.0    0.168869
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1006
# Detected Sign: 1
# Detector cooling
# eg triggered at  1051
# arm
# 1.0     1.000000
# 4.0     0.224110
# 5.0     0.351014
# 6.0     0.627778
# 7.0     0.209082
# 8.0     0.165561
# 11.0    0.040012
# 14.0    0.001755
# 17.0    0.008066
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1664
# Detected Sign: -1
# eg triggered at  1675
# arm
# 1.0     1.000000
# 4.0     0.076562
# 7.0     0.075408
# 11.0    1.000000
# 13.0    0.201489
# 14.0    0.927280
# 17.0    0.181120
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# eg triggered at  1763
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.468320
# 11.0    1.000000
# 14.0    0.578512
# 17.0    0.004110
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 0 IDST_1 time: 199.85861897468567
# Reward change detected at time: 429
# Detected Sign: -1
# Reward change detected at time: 492
# Detected Sign: -1
# eg triggered at  500
# arm
# 1.0     1.000000
# 4.0     0.742925
# 6.0     0.855588
# 7.0     0.810105
# 11.0    0.583474
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  557
# arm
# 1.0     1.000000
# 4.0     0.180879
# 6.0     1.000000
# 7.0     0.132889
# 11.0    0.217216
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# arm
# 5.0     0.147914
# 6.0     0.180971
# 7.0     0.000050
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1007
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1060
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1287
# arm
# 1.0     0.000028
# 4.0     1.000000
# 7.0     0.047586
# 8.0     0.037569
# 11.0    0.346805
# 14.0    0.033116
# 17.0    0.000020
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1500
# Detected Sign: -1
# Detector cooling
# eg triggered at  1528
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.157839
# 11.0    0.755475
# 13.0    1.000000
# 14.0    0.756953
# 17.0    0.737507
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1608
# arm
# 1.0     0.004847
# 4.0     0.290835
# 7.0     1.000000
# 11.0    0.343756
# 13.0    0.353923
# 14.0    0.756806
# 17.0    0.214871
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 1 IDST_1 time: 246.28449273109436
# Reward change detected at time: 543
# Detected Sign: -1
# Detector cooling
# eg triggered at  588
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.485841
# 6.0     0.361258
# 7.0     0.751453
# 11.0    0.375665
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  653
# arm
# 1.0     1.000000
# 4.0     0.704871
# 5.0     0.004033
# 7.0     0.207795
# 11.0    0.375665
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 871
# Detected Sign: -1
# eg triggered at  885
# arm
# 1.0     0.087449
# 4.0     0.922513
# 5.0     0.525265
# 7.0     0.324413
# 11.0    0.613811
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1043
# arm
# 1.0     4.533190e-01
# 4.0     6.606205e-01
# 5.0     6.288450e-01
# 7.0     4.361525e-04
# 11.0    4.284111e-06
# 14.0    8.223558e-05
# 17.0    5.089582e-07
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1357
# Detected Sign: -1
# eg triggered at  1405
# arm
# 1.0     0.288065
# 4.0     0.369467
# 7.0     0.698800
# 11.0    1.000000
# 12.0    0.248187
# 14.0    0.749213
# 17.0    0.075701
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1590
# arm
# 1.0     1.000000
# 4.0     0.648524
# 7.0     0.468653
# 11.0    0.412679
# 12.0    0.882347
# 14.0    1.000000
# 17.0    0.279638
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1752
# arm
# 1.0     1.000000
# 4.0     0.383374
# 7.0     1.000000
# 11.0    1.000000
# 12.0    0.243491
# 14.0    0.340532
# 17.0    0.308779
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 2 IDST_1 time: 161.19646501541138
# Reward change detected at time: 327
# Detected Sign: -1
# eg triggered at  347
# arm
# 1.0     1.000000
# 4.0     0.518893
# 5.0     0.100964
# 6.0     0.620481
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 396
# Detected Sign: -1
# Detector cooling
# eg triggered at  428
# arm
# 1.0     1.000000
# 4.0     0.186620
# 6.0     0.295118
# 7.0     0.750005
# 11.0    0.375730
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  446
# arm
# 1.0     0.542574
# 4.0     0.082072
# 6.0     1.000000
# 7.0     0.750017
# 11.0    0.641167
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1025
# arm
# 1.0     0.005597
# 4.0     0.029231
# 6.0     0.310997
# 7.0     1.000000
# 8.0     0.747064
# 11.0    0.751197
# 14.0    0.423070
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 3 IDST_1 time: 124.46973299980164
# Reward change detected at time: 220
# Detected Sign: -1
# eg triggered at  251
# arm
# 1.0     1.000000
# 4.0     0.856840
# 5.0     0.855944
# 7.0     0.307009
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  313
# arm
# 1.0     1.000000
# 4.0     0.295363
# 5.0     0.012981
# 7.0     0.084558
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 475
# Detected Sign: -1
# eg triggered at  475
# arm
# 1.0     0.615683
# 4.0     0.733483
# 5.0     0.101564
# 7.0     0.345280
# 11.0    0.385819
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  567
# arm
# 1.0     0.319370
# 4.0     0.007721
# 5.0     0.541118
# 7.0     0.307228
# 11.0    1.000000
# 14.0    0.415062
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 622
# Detected Sign: -1
# eg triggered at  647
# arm
# 1.0     0.321236
# 4.0     0.470148
# 5.0     1.000000
# 7.0     0.517417
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  819
# arm
# 1.0     0.319474
# 4.0     0.725864
# 5.0     0.800158
# 7.0     0.735638
# 11.0    0.628423
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: -1
# eg triggered at  1034
# arm
# 1.0     1.000000
# 4.0     0.612995
# 5.0     0.118718
# 6.0     0.099856
# 7.0     1.000000
# 11.0    0.000719
# 14.0    0.002611
# 17.0    0.033543
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1523
# Detected Sign: -1
# eg triggered at  1531
# arm
# 1.0     0.001509
# 4.0     1.000000
# 7.0     0.679633
# 10.0    0.493949
# 11.0    0.522575
# 14.0    0.754661
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1856
# Detected Sign: -1
# Detector cooling
# eg triggered at  1876
# arm
# 1.0     0.089023
# 4.0     0.612787
# 7.0     0.683458
# 10.0    0.297055
# 11.0    0.335996
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 4 IDST_1 time: 206.12046313285828
# trial 5 IDST_1 time: 3.820946216583252
# Reward change detected at time: 501
# Detected Sign: -1
# eg triggered at  501
# arm
# 1.0     0.226173
# 4.0     0.006699
# 7.0     0.173402
# 11.0    0.376006
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1007
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1031
# arm
# 1.0     0.006472
# 4.0     0.003321
# 5.0     0.129345
# 6.0     0.463661
# 7.0     0.327324
# 11.0    0.001014
# 14.0    0.084981
# 17.0    0.000182
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1675
# Detected Sign: -1
# eg triggered at  1681
# arm
# 1.0     0.030082
# 4.0     0.168472
# 7.0     0.669273
# 10.0    0.305289
# 11.0    0.523202
# 14.0    1.000000
# 17.0    0.733688
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1707
# arm
# 1.0     1.000000
# 4.0     0.168257
# 7.0     1.000000
# 10.0    0.939355
# 11.0    0.100662
# 14.0    0.115057
# 17.0    0.149404
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1770
# arm
# 1.0     1.000000
# 4.0     0.540115
# 7.0     1.000000
# 10.0    0.064079
# 11.0    0.750457
# 14.0    0.348753
# 17.0    0.007618
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 6 IDST_1 time: 159.11099004745483
# Reward change detected at time: 322
# Detected Sign: -1
# eg triggered at  356
# arm
# 1.0     0.535939
# 4.0     0.500919
# 5.0     0.152232
# 7.0     0.138092
# 11.0    0.005100
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 974
# Detected Sign: -1
# Reward change detected at time: 1005
# Detected Sign: 1
# eg triggered at  1005
# arm
# 1.0     4.703327e-01
# 4.0     4.021742e-02
# 5.0     3.334819e-01
# 7.0     1.792551e-03
# 11.0    5.663265e-05
# 14.0    1.908945e-08
# 17.0    2.425921e-09
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1365
# Detected Sign: 1
# Detector cooling
# eg triggered at  1382
# arm
# 1.0     1.000000
# 4.0     0.306348
# 7.0     0.698012
# 11.0    0.196608
# 14.0    1.000000
# 17.0    0.638337
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1468
# arm
# 1.0     0.613410
# 4.0     0.628193
# 7.0     0.439086
# 11.0    0.661285
# 14.0    0.213647
# 17.0    0.324807
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1548
# Detected Sign: -1
# Detector cooling
# eg triggered at  1555
# arm
# 1.0     0.613012
# 4.0     1.000000
# 7.0     0.129740
# 10.0    0.299801
# 11.0    0.355195
# 14.0    0.212313
# 17.0    0.630632
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1579
# arm
# 1.0     0.612952
# 4.0     0.629173
# 7.0     0.698270
# 10.0    0.808413
# 11.0    0.111806
# 14.0    0.749193
# 17.0    0.037328
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1768
# arm
# 1.0     0.334899
# 4.0     1.000000
# 7.0     0.687088
# 9.0     0.016681
# 10.0    0.617411
# 11.0    0.756242
# 14.0    0.038339
# 17.0    0.001435
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 7 IDST_1 time: 228.2139551639557
# Reward change detected at time: 451
# Detected Sign: -1
# eg triggered at  488
# arm
# 1.0     1.00000
# 4.0     0.11301
# 7.0     1.00000
# 11.0    1.00000
# 14.0    1.00000
# 17.0    1.00000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  679
# arm
# 1.0     1.000000
# 4.0     0.031621
# 7.0     1.000000
# 11.0    0.561643
# 14.0    0.006474
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1012
# Detected Sign: 1
# Detector cooling
# eg triggered at  1058
# arm
# 1.0     1.000000
# 4.0     0.613591
# 5.0     0.710423
# 6.0     0.121953
# 7.0     0.100482
# 11.0    0.000185
# 14.0    0.000125
# 17.0    0.045751
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1262
# Detected Sign: 1
# eg triggered at  1297
# arm
# 1.0     0.008832
# 4.0     1.000000
# 7.0     0.700797
# 10.0    0.779041
# 11.0    0.333752
# 14.0    0.750274
# 17.0    0.680857
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1333
# arm
# 1.0     1.000000
# 4.0     0.612744
# 7.0     1.000000
# 10.0    0.019256
# 11.0    0.749603
# 14.0    0.199514
# 17.0    0.134503
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1618
# Detected Sign: -1
# eg triggered at  1699
# arm
# 1.0     0.135202
# 4.0     0.275520
# 7.0     1.000000
# 10.0    0.089462
# 11.0    1.000000
# 14.0    0.053056
# 17.0    0.389519
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1808
# arm
# 1.0     0.136917
# 4.0     1.000000
# 7.0     0.131748
# 10.0    0.528148
# 11.0    0.749546
# 14.0    0.522721
# 17.0    0.064232
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1839
# arm
# 1.0     0.137066
# 4.0     1.000000
# 7.0     0.700925
# 10.0    0.500538
# 11.0    0.100453
# 14.0    0.522642
# 17.0    0.012039
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 8 IDST_1 time: 173.94949507713318
# Reward change detected at time: 571
# Detected Sign: -1
# eg triggered at  604
# arm
# 1.0     1.000000
# 4.0     0.856106
# 5.0     0.342524
# 7.0     0.481998
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  770
# arm
# 1.0     1.000000
# 4.0     0.436269
# 7.0     0.156884
# 11.0    0.401232
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1005
# Detected Sign: 1
# eg triggered at  1044
# arm
# 1.0     1.000000
# 4.0     0.047148
# 5.0     0.589698
# 6.0     0.003078
# 7.0     0.119813
# 11.0    0.000002
# 14.0    0.000003
# 17.0    0.000031
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1321
# Detected Sign: -1
# eg triggered at  1339
# arm
# 1.0     0.027882
# 4.0     0.106025
# 7.0     1.000000
# 11.0    0.198753
# 12.0    0.750698
# 13.0    0.765001
# 14.0    0.756721
# 17.0    0.035746
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1368
# arm
# 1.0     0.000341
# 4.0     1.000000
# 7.0     0.471739
# 11.0    0.334977
# 13.0    0.894764
# 14.0    1.000000
# 17.0    0.160863
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1635
# Detected Sign: -1
# Detector cooling
# eg triggered at  1662
# arm
# 1.0     0.030878
# 4.0     0.101333
# 7.0     0.707889
# 11.0    0.333908
# 12.0    0.901959
# 13.0    0.529382
# 14.0    0.354560
# 17.0    0.017402
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1687
# arm
# 1.0     0.030988
# 4.0     0.432013
# 7.0     1.000000
# 11.0    0.526496
# 12.0    0.941510
# 14.0    1.000000
# 17.0    0.012710
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1716
# arm
# 1.0     1.000000
# 4.0     0.101654
# 7.0     0.130424
# 11.0    0.333850
# 12.0    0.161373
# 14.0    1.000000
# 17.0    0.366277
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 1928
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1937
# arm
# 1.0     0.031003
# 4.0     0.431536
# 7.0     0.470146
# 11.0    0.749721
# 12.0    0.686179
# 14.0    1.000000
# 17.0    0.686511
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1996
# arm
# 1.0     0.029785
# 4.0     1.000000
# 7.0     0.706800
# 11.0    0.000078
# 12.0    0.103378
# 14.0    0.002314
# 17.0    0.558731
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDST_1 time: 194.53523898124695

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 875
# Detected Sign: -1
# eg triggered at  904
# arm
# 1.0     0.624271
# 4.0     0.343241
# 5.0     0.315105
# 7.0     1.000000
# 11.0    0.266043
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  914
# arm
# 1.0     0.624130
# 4.0     0.104528
# 5.0     0.421857
# 7.0     0.282290
# 11.0    1.000000
# 14.0    0.006773
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 0 IDS_2 time: 47.49240970611572
# Reward change detected at time: 473
# Detected Sign: -1
# Detector cooling
# eg triggered at  505
# arm
# 1.0     0.483092
# 4.0     0.037104
# 5.0     0.204860
# 6.0     1.000000
# 7.0     0.513684
# 11.0    0.108276
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  531
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.389929
# 7.0     0.755490
# 11.0    0.437797
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 850
# Detected Sign: 1
# eg triggered at  869
# arm
# 1.0     1.000000
# 4.0     0.517333
# 5.0     0.390192
# 7.0     0.755260
# 11.0    0.440977
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  935
# arm
# 1.0     1.000000
# 4.0     0.734589
# 5.0     0.028110
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: 1
# eg triggered at  1051
# arm
# 1.0     1.000000
# 4.0     0.022211
# 7.0     0.632708
# 8.0     0.015175
# 9.0     0.778787
# 10.0    0.074608
# 11.0    1.000000
# 14.0    0.130413
# 17.0    0.005988
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1373
# arm
# 1.0     1.000000e+00
# 4.0     7.812217e-02
# 7.0     1.000000e+00
# 8.0     1.990446e-07
# 9.0     3.487137e-01
# 11.0    2.129467e-01
# 14.0    2.556023e-01
# 17.0    1.311959e-04
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1836
# Detected Sign: -1
# Detector cooling
# eg triggered at  1864
# arm
# 1.0     0.038891
# 4.0     0.158879
# 7.0     0.615875
# 11.0    0.464349
# 14.0    1.000000
# 17.0    0.665346
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 1 IDS_2 time: 87.68712210655212
# Reward change detected at time: 512
# Detected Sign: -1
# eg triggered at  521
# arm
# 1.0     1.000000
# 4.0     0.749638
# 7.0     0.769873
# 11.0    0.551528
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# arm
# 5.0     0.567282
# 6.0     0.848623
# 7.0     0.034889
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1034
# arm
# 1.0     1.000000
# 4.0     0.014429
# 5.0     0.255388
# 6.0     0.815902
# 7.0     1.000000
# 11.0    0.033029
# 14.0    0.000084
# 17.0    0.036432
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1190
# Detected Sign: -1
# eg triggered at  1219
# arm
# 1.0     1.000000
# 4.0     0.003655
# 7.0     0.013565
# 11.0    1.000000
# 14.0    0.954744
# 17.0    0.307582
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDS_2 time: 100.45458698272705
# Reward change detected at time: 344
# Detected Sign: -1
# eg triggered at  344
# arm
# 1.0     0.626743
# 4.0     0.753463
# 6.0     0.119205
# 7.0     0.762316
# 11.0    0.378517
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# arm
# 5.0     0.195043
# 6.0     0.620277
# 7.0     0.818283
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 618
# Detected Sign: 1
# eg triggered at  750
# arm
# 1.0     1.000000
# 4.0     0.519542
# 5.0     0.636021
# 6.0     0.051928
# 7.0     0.535256
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  761
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.665559
# 7.0     0.749237
# 11.0    1.000000
# 14.0    0.167506
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: 1
# eg triggered at  1019
# arm
# 1.0     0.000015
# 4.0     0.022920
# 6.0     1.000000
# 7.0     0.824290
# 8.0     0.635293
# 11.0    0.021396
# 14.0    0.001882
# 17.0    0.008177
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1509
# Detected Sign: -1
# Detector cooling
# eg triggered at  1542
# arm
# 1.0     0.051985
# 4.0     0.617036
# 7.0     1.000000
# 11.0    0.334359
# 13.0    0.444547
# 14.0    0.537239
# 17.0    0.245787
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1620
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     1.000000
# 11.0    1.000000
# 13.0    0.821941
# 14.0    0.057733
# 17.0    0.425600
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 3 IDS_2 time: 88.92448306083679
# Reward change detected at time: 262
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  287
# arm
# 1.0     0.011322
# 4.0     0.219903
# 5.0     0.155039
# 6.0     0.116965
# 7.0     0.755128
# 11.0    0.275013
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  482
# arm
# 1.0     0.401232
# 4.0     0.299225
# 5.0     0.587036
# 7.0     0.511621
# 11.0    0.074627
# 14.0    0.270263
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1027
# arm
# 1.0     1.000000
# 4.0     0.169950
# 5.0     1.000000
# 6.0     0.020167
# 7.0     0.325885
# 8.0     0.861185
# 11.0    0.001113
# 14.0    0.000182
# 17.0    0.105086
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1294
# Detected Sign: -1
# eg triggered at  1306
# arm
# 1.0     1.000000
# 4.0     0.014007
# 7.0     0.406468
# 11.0    0.563075
# 13.0    0.386315
# 14.0    0.531630
# 17.0    0.307782
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1439
# arm
# 1.0     0.000106
# 4.0     0.014967
# 7.0     0.699557
# 11.0    1.000000
# 13.0    0.083588
# 14.0    0.054617
# 17.0    0.620622
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 4 IDS_2 time: 100.47110509872437
# Reward change detected at time: 359
# Detected Sign: -1
# eg triggered at  359
# arm
# 1.0     0.226334
# 4.0     1.000000
# 5.0     1.000000
# 7.0     0.538020
# 11.0    0.689508
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  497
# arm
# 1.0     0.492506
# 4.0     0.736366
# 5.0     0.099591
# 7.0     0.333613
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 553
# Detected Sign: -1
# Detector cooling
# eg triggered at  595
# arm
# 1.0     1.000000
# 4.0     0.159322
# 5.0     0.028555
# 6.0     1.000000
# 7.0     0.197359
# 11.0    0.562447
# 14.0    0.188922
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  711
# arm
# 1.0     1.000000
# 4.0     0.479297
# 5.0     0.019173
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1010
# Detected Sign: 1
# Detector cooling
# eg triggered at  1035
# arm
# 1.0     1.000000
# 4.0     0.000747
# 5.0     0.417218
# 6.0     0.156788
# 7.0     1.000000
# 8.0     1.000000
# 11.0    0.536664
# 14.0    0.005452
# 17.0    0.293863
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1291
# Detected Sign: -1
# eg triggered at  1311
# arm
# 1.0     0.613519
# 4.0     0.703561
# 7.0     0.008255
# 11.0    1.000000
# 12.0    0.575025
# 14.0    0.759130
# 17.0    0.000449
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1979
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# trial 5 IDS_2 time: 126.05751991271973
# Reward change detected at time: 1347
# Detected Sign: 1
# eg triggered at  1383
# arm
# 1.0     1.000000e+00
# 4.0     1.000000e+00
# 5.0     1.130922e-01
# 6.0     5.885758e-01
# 7.0     8.542749e-01
# 11.0    1.341077e-04
# 14.0    3.721515e-07
# 17.0    3.720719e-11
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 6 IDS_2 time: 47.33817791938782
# trial 7 IDS_2 time: 6.469069242477417
# Reward change detected at time: 350
# Detected Sign: -1
# eg triggered at  386
# arm
# 1.0     1.000000
# 4.0     0.607064
# 5.0     0.047051
# 7.0     0.816261
# 11.0    0.577113
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  456
# arm
# 1.0     1.000000
# 4.0     0.019132
# 7.0     0.743160
# 11.0    0.197011
# 14.0    0.020290
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 799
# Detected Sign: 1
# eg triggered at  819
# arm
# 1.0     0.132744
# 4.0     0.577388
# 5.0     1.000000
# 7.0     1.000000
# 11.0    0.577235
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  874
# arm
# 1.0     0.486508
# 4.0     0.614248
# 7.0     1.000000
# 11.0    0.197133
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 944
# Detected Sign: -1
# eg triggered at  966
# arm
# 1.0     0.130886
# 4.0     0.298730
# 5.0     0.537510
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  976
# arm
# 1.0     1.000000
# 4.0     0.338905
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# arm
# 4.0     2.868068e-16
# 5.0     5.771237e-02
# 6.0     7.663130e-03
# 7.0     2.361389e-01
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1332
# Detected Sign: -1
# eg triggered at  1364
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.378937
# 11.0    0.533369
# 12.0    0.772740
# 14.0    0.534554
# 17.0    0.100734
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1633
# arm
# 1.0     1.000000
# 4.0     0.000238
# 7.0     1.000000
# 11.0    0.001463
# 12.0    0.391064
# 14.0    0.209569
# 17.0    0.110482
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 8 IDS_2 time: 129.06887102127075
# Reward change detected at time: 381
# Detected Sign: -1
# eg triggered at  381
# arm
# 1.0     1.000000
# 4.0     0.180719
# 5.0     0.536809
# 7.0     0.749474
# 11.0    0.386186
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  562
# arm
# 1.0     1.000000
# 4.0     0.133867
# 5.0     0.205242
# 7.0     1.000000
# 11.0    0.615118
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1062
# arm
# 1.0     1.000000
# 4.0     0.277148
# 5.0     0.004425
# 6.0     0.692723
# 7.0     0.433219
# 11.0    0.001041
# 14.0    0.000323
# 17.0    0.000241
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1783
# Detected Sign: -1
# eg triggered at  1814
# arm
# 1.0     1.000000
# 4.0     0.000168
# 7.0     0.205822
# 9.0     0.723332
# 11.0    0.851181
# 12.0    0.674841
# 14.0    0.109595
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDS_2 time: 100.82173585891724
# Reward change detected at time: 899
# Detected Sign: -1
# eg triggered at  942
# arm
# 1.0     1.000000
# 4.0     0.185535
# 5.0     0.248123
# 7.0     0.497872
# 11.0    1.000000
# 14.0    0.093050
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: 1
# eg triggered at  1052
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.070009
# 7.0     0.106412
# 11.0    0.000031
# 14.0    0.000004
# 17.0    0.000014
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1657
# Detected Sign: -1
# eg triggered at  1693
# arm
# 1.0     1.000000
# 4.0     0.180506
# 7.0     0.045900
# 11.0    0.332848
# 12.0    0.522499
# 14.0    0.022927
# 17.0    0.060072
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1821
# Detected Sign: -1
# eg triggered at  1850
# arm
# 1.0     0.058695
# 4.0     1.000000
# 7.0     0.189031
# 11.0    0.751663
# 12.0    0.680297
# 14.0    0.757161
# 17.0    0.070797
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1965
# Detected Sign: -1
# trial 0 IDS_3 time: 98.67116498947144
# Reward change detected at time: 269
# Detected Sign: -1
# eg triggered at  299
# arm
# 1.0     0.596383
# 4.0     0.168010
# 5.0     0.026480
# 6.0     0.634478
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  620
# arm
# 1.0     1.000000e+00
# 4.0     4.094684e-02
# 5.0     8.585099e-08
# 7.0     7.492245e-01
# 11.0    6.126123e-01
# 14.0    1.000000e+00
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1022
# Detected Sign: 1
# eg triggered at  1037
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     1.000000
# 6.0     0.486062
# 7.0     0.344888
# 11.0    0.228163
# 14.0    0.075804
# 17.0    0.000004
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1405
# Detected Sign: -1
# Detector cooling
# eg triggered at  1414
# arm
# 1.0     0.025675
# 4.0     0.191786
# 7.0     0.725724
# 11.0    0.330624
# 14.0    0.202237
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1459
# arm
# 1.0     0.000240
# 4.0     0.377919
# 7.0     1.000000
# 11.0    0.238431
# 14.0    0.121440
# 17.0    0.486192
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 1 IDS_3 time: 127.78198099136353
# Reward change detected at time: 570
# Detected Sign: -1
# eg triggered at  599
# arm
# 1.0     1.000000
# 4.0     0.281681
# 5.0     0.904798
# 7.0     0.016997
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 799
# Detected Sign: -1
# eg triggered at  804
# arm
# 1.0     1.000000
# 4.0     0.717848
# 5.0     0.379823
# 6.0     0.535537
# 7.0     1.000000
# 11.0    0.351134
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: -1
# eg triggered at  1052
# arm
# 1.0     0.005487
# 4.0     1.000000
# 6.0     0.570403
# 7.0     0.324867
# 8.0     0.263688
# 11.0    0.525489
# 14.0    0.015349
# 17.0    0.000824
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDS_3 time: 75.78204727172852
# Reward change detected at time: 243
# Detected Sign: -1
# Detector cooling
# eg triggered at  306
# arm
# 1.0     0.612654
# 4.0     0.734645
# 5.0     0.007969
# 6.0     0.737806
# 7.0     0.014052
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  414
# arm
# 1.0     0.612592
# 4.0     0.485938
# 5.0     0.055693
# 7.0     0.753208
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 543
# Detected Sign: -1
# eg triggered at  619
# arm
# 1.0     0.579417
# 4.0     1.000000
# 5.0     0.080379
# 7.0     0.653155
# 11.0    0.617651
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# eg triggered at  689
# arm
# 1.0     1.000000
# 4.0     0.161597
# 5.0     0.571510
# 7.0     0.203869
# 11.0    0.096839
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: 1
# eg triggered at  1055
# arm
# 1.0     0.005482
# 4.0     0.000777
# 6.0     0.001578
# 7.0     0.049866
# 8.0     0.345386
# 9.0     1.000000
# 11.0    1.000000
# 14.0    0.477958
# 17.0    0.005858
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1300
# Detected Sign: -1
# eg triggered at  1349
# arm
# 1.0     1.000000
# 4.0     0.234870
# 7.0     0.669634
# 11.0    0.456013
# 14.0    0.028529
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1578
# arm
# 1.0     0.004302
# 4.0     0.612604
# 7.0     1.000000
# 11.0    0.309509
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1979
# Detected Sign: -1
# Detector cooling
# trial 3 IDS_3 time: 125.6364381313324
# Reward change detected at time: 688
# Detected Sign: -1
# eg triggered at  709
# arm
# 1.0     1.000000
# 4.0     0.337605
# 5.0     0.121866
# 6.0     0.709437
# 7.0     0.530272
# 8.0     0.318791
# 11.0    0.592490
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 817
# Detected Sign: -1
# eg triggered at  843
# arm
# 1.0     1.000000
# 4.0     0.510328
# 6.0     0.715376
# 7.0     0.339893
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 887
# Detected Sign: -1
# eg triggered at  894
# arm
# 1.0     0.011685
# 4.0     0.102911
# 6.0     0.316847
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  966
# arm
# 1.0     1.000000
# 4.0     0.510391
# 6.0     0.086777
# 7.0     1.000000
# 11.0    0.270476
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1003
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1069
# arm
# 1.0     1.000000
# 4.0     0.010746
# 6.0     1.000000
# 7.0     0.919753
# 8.0     1.000000
# 11.0    0.022373
# 14.0    0.013105
# 17.0    0.039097
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1092
# arm
# 1.0     1.000000
# 4.0     0.150100
# 7.0     0.282531
# 11.0    0.108481
# 14.0    0.001977
# 17.0    0.025086
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1894
# Detected Sign: -1
# Detector cooling
# eg triggered at  1908
# arm
# 1.0     0.015332
# 4.0     1.000000
# 7.0     0.650479
# 11.0    0.104434
# 12.0    0.714065
# 13.0    0.713607
# 14.0    0.217368
# 17.0    0.510628
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 4 IDS_3 time: 99.4427547454834
# Reward change detected at time: 160
# Detected Sign: -1
# Detector cooling
# eg triggered at  183
# arm
# 1.0     0.151809
# 4.0     0.425799
# 5.0     0.397776
# 7.0     0.040391
# 8.0     0.299246
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  433
# arm
# 1.0     0.151826
# 4.0     0.000002
# 7.0     1.000000
# 11.0    1.000000
# 14.0    0.002654
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 773
# Detected Sign: -1
# eg triggered at  826
# arm
# 1.0     0.376440
# 4.0     0.342208
# 6.0     0.089217
# 7.0     0.199018
# 8.0     0.502636
# 11.0    0.458830
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  991
# arm
# 1.0     1.000000
# 4.0     0.510173
# 6.0     0.979993
# 7.0     1.000000
# 11.0    0.515830
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# arm
# 6.0     0.021774
# 7.0     1.000000
# 8.0     0.820954
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 1162
# Detected Sign: -1
# eg triggered at  1174
# arm
# 1.0     0.005516
# 4.0     0.118507
# 7.0     1.000000
# 8.0     0.217118
# 9.0     0.510137
# 11.0    0.205788
# 14.0    0.017101
# 17.0    0.000015
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1479
# Detected Sign: -1
# eg triggered at  1485
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.454879
# 9.0     1.000000
# 11.0    0.362038
# 14.0    0.749438
# 17.0    0.062361
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1500
# arm
# 1.0     0.158357
# 4.0     0.111540
# 7.0     0.236302
# 9.0     0.906787
# 11.0    1.000000
# 14.0    0.749471
# 17.0    0.033722
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1908
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1915
# arm
# 1.0     0.008491
# 4.0     0.355633
# 7.0     0.650309
# 11.0    0.203525
# 14.0    0.525362
# 17.0    0.301858
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 5 IDS_3 time: 127.25817704200745
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# eg triggered at  1036
# arm
# 1.0     0.000014
# 4.0     0.352303
# 5.0     0.020897
# 6.0     0.392512
# 7.0     0.146387
# 11.0    0.492293
# 14.0    0.042535
# 17.0    0.000040
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1740
# Detected Sign: -1
# eg triggered at  1740
# arm
# 1.0     0.166279
# 4.0     0.225922
# 7.0     1.000000
# 11.0    1.000000
# 14.0    0.107033
# 17.0    0.257255
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1787
# arm
# 1.0     0.000562
# 4.0     1.000000
# 7.0     1.000000
# 11.0    0.504059
# 14.0    0.752754
# 17.0    0.103587
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 6 IDS_3 time: 85.04387307167053
# Reward change detected at time: 1004
# Detected Sign: -1
# eg triggered at  1037
# arm
# 1.0     1.000000
# 4.0     0.003124
# 7.0     0.782434
# 8.0     0.537356
# 11.0    0.334935
# 14.0    0.000305
# 17.0    0.005393
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 7 IDS_3 time: 48.776121854782104
# Reward change detected at time: 234
# Detected Sign: 1
# Reward change detected at time: 344
# Detected Sign: -1
# eg triggered at  371
# arm
# 1.0     0.438220
# 4.0     0.306408
# 6.0     0.904785
# 7.0     0.756306
# 11.0    0.375909
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  806
# arm
# 1.0     4.412436e-01
# 4.0     7.351288e-01
# 5.0     1.038641e-01
# 6.0     2.018605e-08
# 7.0     5.290446e-01
# 11.0    1.000000e+00
# 14.0    1.000000e+00
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1003
# Detected Sign: -1
# Detector cooling
# eg triggered at  1094
# arm
# 1.0     0.005559
# 4.0     0.000078
# 6.0     1.000000
# 7.0     0.001368
# 11.0    0.334735
# 14.0    0.001796
# 17.0    0.000545
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1323
# Detected Sign: -1
# Detector cooling
# eg triggered at  1344
# arm
# 1.0     1.000000
# 4.0     0.618878
# 7.0     0.050753
# 10.0    0.719161
# 11.0    0.537944
# 14.0    0.488358
# 17.0    0.012951
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1443
# arm
# 1.0     0.108025
# 4.0     1.000000
# 7.0     0.472659
# 10.0    0.247879
# 11.0    0.018843
# 14.0    0.162236
# 17.0    0.009640
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1812
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1825
# arm
# 1.0     0.125762
# 4.0     1.000000
# 7.0     0.245342
# 10.0    0.417586
# 11.0    0.333972
# 14.0    0.008434
# 17.0    0.060854
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1881
# arm
# 1.0     1.000000
# 4.0     0.618318
# 7.0     0.130686
# 10.0    1.000000
# 11.0    0.749275
# 14.0    1.000000
# 17.0    0.009726
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 8 IDS_3 time: 127.14941596984863
# Reward change detected at time: 993
# Detected Sign: -1
# eg triggered at  1024
# arm
# 1.0     0.021269
# 4.0     0.062555
# 5.0     0.885933
# 6.0     0.567394
# 7.0     0.527622
# 8.0     0.352747
# 11.0    0.237306
# 14.0    0.000019
# 17.0    0.070121
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1762
# Detected Sign: -1
# eg triggered at  1771
# arm
# 1.0     0.081019
# 4.0     0.130916
# 7.0     1.000000
# 11.0    1.000000
# 14.0    0.703027
# 17.0    0.033285
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1888
# Detected Sign: 1
# eg triggered at  1904
# arm
# 1.0     1.000000
# 4.0     0.372475
# 7.0     0.707239
# 11.0    0.751912
# 14.0    0.602756
# 17.0    0.437936
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 9 IDS_3 time: 72.51670789718628

# %%
#IDS without transferability test
IDSN_df = pd.DataFrame()
IDSN_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDSN = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDSN_sum, IDSN_pt, IDSN_re, IDSN_arm, IDSN_post = IDSN.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDSN time:',end-start)
    IDSN_df = IDSN_df.append([np.cumsum(IDSN_re)])
    IDSN_df_arm = IDSN_df_arm.append([IDSN_arm])
    
#IDS with window likelihood
IDSW_df = pd.DataFrame()
IDSW_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDSW = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0, update_during_exploit=True,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDSW_sum, IDSW_pt, IDSW_re, IDSW_arm, IDSW_post = IDSW.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDSW time:',end-start)
    IDSW_df = IDSW_df.append([np.cumsum(IDSW_re)])
    IDSW_df_arm = IDSW_df_arm.append([IDSW_arm])
# Out:
# Reward change detected at time: 256
# Detected Sign: -1
# Reward change detected at time: 1006
# Detected Sign: 1
# Detector cooling
# trial 0 IDSN time: 37.285078048706055
# Reward change detected at time: 187
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 333
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 622
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1005
# Detected Sign: 1
# Reward change detected at time: 1423
# Detected Sign: 1
# Detector cooling
# Detector cooling
# trial 1 IDSN time: 76.09910678863525
# Reward change detected at time: 436
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 673
# Detected Sign: -1
# Reward change detected at time: 901
# Detected Sign: -1
# Reward change detected at time: 1010
# Detected Sign: 1
# Reward change detected at time: 1617
# Detected Sign: 1
# Reward change detected at time: 1724
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1804
# Detected Sign: -1
# Reward change detected at time: 1874
# Detected Sign: 1
# trial 2 IDSN time: 111.22177791595459
# Reward change detected at time: 238
# Detected Sign: -1
# Reward change detected at time: 363
# Detected Sign: -1
# Reward change detected at time: 716
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1011
# Detected Sign: 1
# Reward change detected at time: 1409
# Detected Sign: -1
# Reward change detected at time: 1551
# Detected Sign: -1
# trial 3 IDSN time: 88.09964203834534
# Reward change detected at time: 543
# Detected Sign: -1
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# trial 4 IDSN time: 36.712706089019775
# trial 5 IDSN time: 6.632178068161011
# Reward change detected at time: 506
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 710
# Detected Sign: -1
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1594
# Detected Sign: -1
# trial 6 IDSN time: 61.24491620063782
# Reward change detected at time: 1012
# Detected Sign: 1
# Reward change detected at time: 1786
# Detected Sign: -1
# trial 7 IDSN time: 34.675562143325806
# Reward change detected at time: 585
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 626
# Detected Sign: -1
# Reward change detected at time: 1013
# Detected Sign: 1
# trial 8 IDSN time: 48.388570070266724
# Reward change detected at time: 191
# Detected Sign: 1
# Reward change detected at time: 382
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 435
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 670
# Detected Sign: -1
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1844
# Detected Sign: -1
# trial 9 IDSN time: 88.76608371734619
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-446c26f7d2f8> in <module>
#      19 for i in range(trial_rounds):
#      20     start = time.time()
# ---> 21     IDSW = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0, update_during_exploit=True,
#      22                      simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
#      23     IDSW_sum, IDSW_pt, IDSW_re, IDSW_arm, IDSW_post = IDSW.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
#
# TypeError: __init__() got an unexpected keyword argument 'update_during_exploit'

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=False, tuned=True)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.7328789234161377
# trial 1 UCB_1 time: 0.7326810359954834
# trial 2 UCB_1 time: 0.7340998649597168
# trial 3 UCB_1 time: 0.7333049774169922
# trial 4 UCB_1 time: 0.7370028495788574
# trial 5 UCB_1 time: 0.7342090606689453
# trial 6 UCB_1 time: 0.7337033748626709
# trial 7 UCB_1 time: 0.7332367897033691
# trial 8 UCB_1 time: 0.7335038185119629
# trial 9 UCB_1 time: 0.7324299812316895
# trial 0 UCB_2 time: 0.7346742153167725
# trial 1 UCB_2 time: 0.7328720092773438
# trial 2 UCB_2 time: 0.7331860065460205
# trial 3 UCB_2 time: 0.7329869270324707
# trial 4 UCB_2 time: 0.7329230308532715
# trial 5 UCB_2 time: 0.7326350212097168
# trial 6 UCB_2 time: 0.7327558994293213
# trial 7 UCB_2 time: 0.7349820137023926
# trial 8 UCB_2 time: 0.7316720485687256
# trial 9 UCB_2 time: 0.7322478294372559
# trial 0 UCB-tuned time: 1.4544329643249512
# trial 1 UCB-tuned time: 1.401465892791748
# trial 2 UCB-tuned time: 1.4413440227508545
# trial 3 UCB-tuned time: 1.4091320037841797
# trial 4 UCB-tuned time: 1.3949990272521973
# trial 5 UCB-tuned time: 1.405256986618042
# trial 6 UCB-tuned time: 1.4201741218566895
# trial 7 UCB-tuned time: 1.4799370765686035
# trial 8 UCB-tuned time: 1.366673231124878
# trial 9 UCB-tuned time: 1.5205860137939453
# trial 0 UCBPI time: 0.9320800304412842
# trial 1 UCBPI time: 0.9339778423309326
# trial 2 UCBPI time: 0.9319741725921631
# trial 3 UCBPI time: 1.2426741123199463
# trial 4 UCBPI time: 0.9323770999908447
# trial 5 UCBPI time: 0.9334828853607178
# trial 6 UCBPI time: 1.274740219116211
# trial 7 UCBPI time: 1.2450368404388428
# trial 8 UCBPI time: 0.9331839084625244
# trial 9 UCBPI time: 1.2395997047424316
# trial 0 TS time: 1.5154259204864502
# trial 1 TS time: 1.5116372108459473
# trial 2 TS time: 1.5072598457336426
# trial 3 TS time: 1.5143117904663086
# trial 4 TS time: 1.5083739757537842
# trial 5 TS time: 1.5209717750549316
# trial 6 TS time: 1.5190651416778564
# trial 7 TS time: 1.5176150798797607
# trial 8 TS time: 1.5154781341552734
# trial 9 TS time: 1.5216648578643799
# trial 0 EG 0.05 time: 0.1384568214416504
# trial 1 EG 0.05 time: 0.13997411727905273
# trial 2 EG 0.05 time: 0.13942313194274902
# trial 3 EG 0.05 time: 0.13892078399658203
# trial 4 EG 0.05 time: 0.13926982879638672
# trial 5 EG 0.05 time: 0.1394648551940918
# trial 6 EG 0.05 time: 0.13846707344055176
# trial 7 EG 0.05 time: 0.1393139362335205
# trial 8 EG 0.05 time: 0.13908886909484863
# trial 9 EG 0.05 time: 0.13925409317016602
# trial 0 EG 0.1 time: 0.1370398998260498
# trial 1 EG 0.1 time: 0.13688206672668457
# trial 2 EG 0.1 time: 0.13967585563659668
# trial 3 EG 0.1 time: 0.13837218284606934
# trial 4 EG 0.1 time: 0.13849210739135742
# trial 5 EG 0.1 time: 0.13777518272399902
# trial 6 EG 0.1 time: 0.1389789581298828
# trial 7 EG 0.1 time: 0.1393451690673828
# trial 8 EG 0.1 time: 0.13891100883483887
# trial 9 EG 0.1 time: 0.1394820213317871
# trial 0 EG 0.15 time: 0.13878917694091797
# trial 1 EG 0.15 time: 0.13821005821228027
# trial 2 EG 0.15 time: 0.13768887519836426
# trial 3 EG 0.15 time: 0.13844990730285645
# trial 4 EG 0.15 time: 0.13768506050109863
# trial 5 EG 0.15 time: 0.13786888122558594
# trial 6 EG 0.15 time: 0.13852596282958984
# trial 7 EG 0.15 time: 0.1371152400970459
# trial 8 EG 0.15 time: 0.13827991485595703
# trial 9 EG 0.15 time: 0.1386430263519287

# %%
IDS_1_df = IDS_1_df.iloc[:,:2000]
IDS_2_df = IDS_2_df.iloc[:,:2000]
IDS_3_df = IDS_3_df.iloc[:,:2000]
IDST_1_df = IDST_1_df.iloc[:,:2000]
IDS_1_df_arm = IDS_1_df_arm.iloc[:,:2000]
IDS_2_df_arm = IDS_2_df_arm.iloc[:,:2000]
IDS_3_df_arm = IDS_3_df_arm.iloc[:,:2000]
# IDST_1_df_arm = IDST_1_df_arm.iloc[:,:2000]

# %%
def draw_exp_graph(IDS_1, IDS_2, IDS_3, IDST_1, UCB_1, UCB_2, UCBT, UCBPI, TS, EG_1, EG_2, EG_3, title):
    
    IDS_1_mean = IDS_1.mean()
    IDS_2_mean = IDS_2.mean()
    IDS_3_mean = IDS_3.mean()
    IDST_1_mean = IDST_1.mean()
    UCB_1_mean = UCB_1.mean()
    UCB_2_mean =UCB_2.mean()
    UCBT_mean = UCBT.mean()
    UCBPI_mean = UCBPI.mean()
    TS_mean = TS.mean()
    EG_1_mean = EG_1.mean()
    EG_2_mean = EG_2.mean()
    EG_3_mean = EG_3.mean()
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.fill_between(T, EG_1.min(), EG_1.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')
    plt.fill_between(T, EG_2.min(), EG_2.max(), color='#000000', alpha=0.1)
    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    plt.fill_between(T, EG_3.min(), EG_3.max(), color='#000000', alpha=0.1)
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    plt.fill_between(T, TS.min(), TS.max(), color='#666666', alpha=0.2)
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.fill_between(T, UCB_1.min(), UCB_1.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.fill_between(T, UCB_2.min(), UCB_2.max(), color='#666600', alpha=0.2)
    
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.fill_between(T, UCBT.min(), UCBT.max(), color='#666600', alpha=0.2)

    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')
    plt.fill_between(T, UCBPI.min(), UCBPI.max(), color='#666600', alpha=0.2)

    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.fill_between(T, IDS_1.min(), IDS_1.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.fill_between(T, IDS_2.min(), IDS_2.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.fill_between(T, IDS_3.min(), IDS_3.max(), color='#FF6666', alpha=0.2)

    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.fill_between(T, IDST_1.min(), IDST_1.max(), color='#FF6666', alpha=0.2)
    
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned', 'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2', 'IDS Theta'],
              bbox_to_anchor=(0.85, -0.05), ncol=6, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Reward')
    plt.show()

# %%
title = 'Case 6: Distribution Shift'
draw_exp_graph(IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df,UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title)

# %%
draw_arm(IDS_1_df_arm, IDS_2_df_arm, IDS_3_df_arm, EG_1_df_arm)

# %%
# import matplotlib.patches as mpatches
# def draw_exp_graph(IDS_1,IDST_1,UCB,UCBPI,TS, EG):
#     IDS_1_mean = IDS_1.mean()
#     IDST_1_mean = IDST_1.mean()
#     UCB_mean = UCB.mean()
#     UCBPI_mean = UCBPI.mean()
#     TS_mean = TS.mean()
#     EG_mean = EG.mean()
    
#     plt.figure(figsize=(30,20))
#     sns.set(font_scale=2)
    
#     T = EG.shape[1]
    
#     for i in range(EG.shape[0]):
#         plt.plot(EG.iloc[i],alpha=0.2,color='yellow')
#     plt.plot(EG_mean,alpha=1,color='yellow')
#     plt.fill_between(np.arange(T), EG.min(), EG.max(), color='yellow', alpha=0.2)
    
#     for i in range(TS.shape[0]):
#         plt.plot(TS.iloc[i],alpha=0.2,color='purple')
#     plt.plot(TS_mean,alpha=1,color='purple')
#     plt.fill_between(np.arange(T), TS.min(), TS.max(), color='purple', alpha=0.2)
    
#     for i in range(UCB.shape[0]):
#         plt.plot(UCB.iloc[i],alpha=0.2,color='gray')
#     plt.plot(UCB_mean,alpha=1,color='gray')
#     plt.fill_between(np.arange(T), UCB.min(), UCB.max(), color='gray', alpha=0.2)
    
#     for i in range(UCBPI.shape[0]):
#         plt.plot(UCBPI.iloc[i],alpha=0.2,color='black')
#     plt.plot(UCBPI_mean,alpha=1,color='black')
#     plt.fill_between(np.arange(T), UCBPI.min(), UCBPI.max(), color='black', alpha=0.2)

#     for i in range(IDS_1.shape[0]):
#         plt.plot(IDS_1.iloc[i],alpha=0.2,color='red')
#     plt.plot(IDS_1_mean,alpha=1,color='red')
#     plt.fill_between(np.arange(T), IDS_1.min(), IDS_1.max(), color='red', alpha=0.2)
    
#     for i in range(IDST_1.shape[0]):
#         plt.plot(IDST_1.iloc[i],alpha=0.2,color='blue')
#     plt.plot(IDST_1_mean,alpha=1,color='blue')
#     plt.fill_between(np.arange(T), IDST_1.min(), IDST_1.max(), color='blue', alpha=0.2)
    
#     leg_UCB = mpatches.Patch(color='gray', label='UCB')
#     leg_UCBPI = mpatches.Patch(color='black', label='UCBPI')
#     leg_IDS_1 = mpatches.Patch(color='red', label='IDS_1')
#     leg_IDST_1 = mpatches.Patch(color='blue', label='IDST_1')
#     leg_TS = mpatches.Patch(color='purple', label='TS')
#     leg_EG = mpatches.Patch(color='yellow', label='EG')
    
#     plt.legend(handles=[leg_UCB, leg_UCBPI, leg_IDS_1, leg_IDST_1, leg_TS, leg_EG], loc= 'lower right')
#     plt.xlim([0, T])
#     plt.show()

    
# draw_exp_graph(IDS_1_df,IDST_1_df,UCB_df,UCBPI_df,TS_df,EG_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3ba781281eae> in <module>
#      55
#      56
# ---> 57 draw_exp_graph(IDS_1_df,IDST_1_df,UCB_df,UCBPI_df,TS_df,EG_df)
#
# NameError: name 'UCB_df' is not defined

# %%
# sns.set(font_scale=1)
# print('IDS_1')
# plt.plot(IDS_1_arm)
# plt.show()
# print(IDS_1_re[-300:].mean())
# print('collection rounds:', IDS_1.collection_rounds)

# print('IDS_2')
# plt.plot(IDS_2_arm)
# plt.show()
# print(IDS_2_re[-300:].mean())
# print('collection rounds:', IDS_2.collection_rounds)

# print('IDS_3')
# plt.plot(IDS_3_arm)
# plt.show()
# print(IDS_3_re[-300:].mean())
# print('collection rounds:', IDS_3.collection_rounds)

# print('IDST_1')
# plt.plot(IDST_1_arm)
# plt.show()
# print(IDST_1_re[-300:].mean())
# print('collection rounds:', IDST_1.collection_rounds)

# print('UCB1')
# plt.plot(UCB1_arm)
# plt.show()
# print(UCB1_re[-300:].mean())

# print('UCBPI')
# plt.plot(UCBPI_arm)
# plt.show()
# print(UCBPI_re[-300:].mean())

# print('TS')
# plt.plot(TS_arm)
# plt.show()
# print(TS_re[-300:].mean())

# print('EG')
# plt.plot(EG_arm)
# plt.show()
# print(EG_re[-300:].mean())

# %%
#Est
sns.lineplot(data=IDS_1.get_p_a_y() @ np.linspace(1, 10, 11), color='blue')
sns.lineplot(data=IDST_1.get_p_a_y() @ np.linspace(1, 10, 11), color='green')
#True
df2['demand'] = df2['reward'] / df2['price']
sns.lineplot(data=df2.groupby('arm').demand.mean(), color='red')
plt.show()

# %%
#Est
sns.lineplot(data=IDS_1.get_p_a_y() @ np.linspace(1, 10, 11) * price_list, color='blue')
sns.lineplot(data=IDST_1.get_p_a_y() @ np.linspace(1, 10, 11) * price_list, color='green')
#True
df2['demand'] = df2['reward'] / df2['price']
sns.lineplot(data=df2.groupby('arm').demand.mean() * price_list, color='red')
plt.ylabel('revenue')
plt.show()
