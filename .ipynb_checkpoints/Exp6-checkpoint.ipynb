# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import time
from algo import *
from util import *
from environment import *
from ids import *

# %%
def set_experiment6(price_list=np.linspace(0.01,1,100), segments=1000, update_freq=10, T=2000):
    start = time.time()
    exp_MAB_1 = pricing_MAB(price_list=price_list, segments=segments,update_freq=update_freq, exp='exp6', T=T)
    exp_MAB_1.segments_means(param1=3,param2=6)
    df1, df2 = exp_MAB_1.true_optimal()
    print('time:',time.time()-start)
    return exp_MAB_1, df1, df2

# %%
#changeable parameters
np.random.seed(555)
price_list=np.linspace(0.01,1,20)
T = 2000

#fix parameters
segments = 1000
update_freq = 10
trial_rounds = 10
exp_MAB_1, df1, df2 = set_experiment6(price_list=price_list, segments=segments, update_freq =10, T=T)
sns.kdeplot(exp_MAB_1.seg_means, color='orange')
sns.kdeplot(exp_MAB_1.seg_means_2)
# Out:
# The true optimal arm in first 1000 rounds is: 5
# The true optimal arm in the rest is: 13
# time: 25.139428853988647
# <AxesSubplot:ylabel='Density'>

# %%
#IDS_1
IDS_1_df = pd.DataFrame()
IDS_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_1 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_1_sum, IDS_1_pt, IDS_1_re, IDS_1_arm, IDS_1_post = IDS_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_1 time:',end-start)
    exp_MAB_1.reset_t()
    IDS_1_df = IDS_1_df.append([np.cumsum(IDS_1_re)])
    IDS_1_df_arm = IDS_1_df_arm.append([IDS_1_arm])
# Out:
# Reward change detected at time: 712
# Detected Sign: -1
# eg triggered at  753
# arm
# 1.0     1.000000
# 3.0     0.474049
# 4.0     0.299664
# 5.0     0.308918
# 6.0     0.904975
# 7.0     0.007457
# 8.0     0.036712
# 11.0    0.612615
# 14.0    0.045040
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  787
# arm
# 1.0     0.088756
# 4.0     0.076459
# 5.0     0.854301
# 7.0     0.214716
# 11.0    0.612581
# 14.0    0.041718
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 947
# Detected Sign: 1
# eg triggered at  955
# arm
# 1.0     0.402803
# 4.0     1.000000
# 5.0     0.301721
# 6.0     0.343750
# 7.0     0.101998
# 11.0    0.612637
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# Reward change detected at time: 1006
# Detected Sign: 1
# eg triggered at  1100
# arm
# 1.0     0.005488
# 4.0     0.012493
# 5.0     0.001027
# 6.0     0.635968
# 7.0     0.136193
# 8.0     0.295571
# 11.0    0.750786
# 14.0    0.018131
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1692
# Detected Sign: -1
# eg triggered at  1735
# arm
# 1.0     0.608521
# 4.0     1.000000
# 7.0     0.280184
# 11.0    0.563921
# 14.0    0.190778
# 17.0    0.217504
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1773
# arm
# 1.0     0.612777
# 4.0     1.000000
# 7.0     0.720449
# 11.0    0.238608
# 14.0    0.193419
# 17.0    0.113124
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Detector cooling
# Detector cooling
# trial 0 IDS_1 time: 84.45743680000305
# Reward change detected at time: 771
# Detected Sign: -1
# eg triggered at  779
# arm
# 1.0     0.226480
# 4.0     0.333448
# 5.0     0.485913
# 6.0     1.000000
# 7.0     0.011377
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1007
# Detected Sign: 1
# Detector cooling
# eg triggered at  1034
# arm
# 1.0     1.000000
# 4.0     0.011691
# 5.0     0.442540
# 6.0     0.092488
# 7.0     0.558330
# 8.0     0.327187
# 11.0    0.195379
# 14.0    1.000000
# 17.0    0.094168
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1074
# arm
# 1.0     1.000000
# 4.0     0.000533
# 7.0     0.443247
# 8.0     0.813227
# 11.0    0.049926
# 14.0    0.000133
# 17.0    0.084637
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1984
# Detected Sign: -1
# eg triggered at  1984
# arm
# 1.0     1.000000
# 4.0     0.629234
# 7.0     0.735819
# 11.0    0.120809
# 14.0    0.354183
# 15.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 1 IDS_1 time: 71.3261330127716
# Reward change detected at time: 247
# Detected Sign: -1
# Detector cooling
# eg triggered at  306
# arm
# 1.0     1.000000
# 4.0     0.299039
# 5.0     0.794947
# 6.0     0.243004
# 7.0     0.750917
# 11.0    0.366120
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  515
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.205107
# 7.0     0.535908
# 11.0    0.625327
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1004
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1043
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.091066
# 7.0     0.402156
# 8.0     0.434693
# 11.0    0.755364
# 14.0    0.000511
# 17.0    0.000053
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDS_1 time: 61.18235778808594
# trial 3 IDS_1 time: 5.741369009017944
# Reward change detected at time: 242
# Detected Sign: -1
# eg triggered at  307
# arm
# 1.0     1.000000
# 4.0     0.467358
# 5.0     0.040935
# 6.0     0.005523
# 7.0     0.575456
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 510
# Detected Sign: -1
# eg triggered at  538
# arm
# 1.0     1.000000
# 4.0     0.157728
# 5.0     0.510127
# 7.0     0.751006
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  553
# arm
# 1.0     1.000000
# 4.0     0.735177
# 5.0     0.066678
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# eg triggered at  1043
# arm
# 1.0     0.000019
# 4.0     0.356835
# 5.0     1.000000
# 6.0     0.699688
# 7.0     0.605769
# 11.0    0.001135
# 14.0    0.000437
# 17.0    0.027693
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1881
# Detected Sign: 1
# eg triggered at  1899
# arm
# 1.0     0.534959
# 4.0     1.000000
# 7.0     0.698061
# 10.0    0.597634
# 11.0    1.000000
# 14.0    0.074128
# 17.0    0.004949
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 4 IDS_1 time: 134.11403584480286
# Reward change detected at time: 1004
# Detected Sign: -1
# eg triggered at  1069
# arm
# 1.0     1.000000
# 4.0     0.000603
# 6.0     0.004819
# 7.0     0.881540
# 8.0     0.119887
# 11.0    0.334944
# 14.0    0.426636
# 17.0    0.473092
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 5 IDS_1 time: 46.611974000930786
# Reward change detected at time: 382
# Detected Sign: -1
# eg triggered at  420
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.307829
# 7.0     0.534459
# 11.0    0.408997
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  777
# arm
# 1.0     1.000000e+00
# 4.0     5.276011e-01
# 5.0     9.533857e-08
# 7.0     7.491774e-01
# 11.0    4.043758e-01
# 14.0    1.000000e+00
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1007
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 1048
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1079
# arm
# 1.0     1.000000e+00
# 4.0     1.077160e-02
# 7.0     2.395789e-01
# 8.0     6.407219e-01
# 11.0    7.540201e-01
# 14.0    1.069446e-02
# 17.0    8.998106e-07
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1964
# Detected Sign: -1
# eg triggered at  1980
# arm
# 1.0     1.000000
# 4.0     0.093778
# 7.0     0.299057
# 11.0    1.000000
# 12.0    0.468637
# 13.0    0.352149
# 14.0    0.348252
# 17.0    0.375756
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 6 IDS_1 time: 109.9775378704071
# Reward change detected at time: 1003
# Detected Sign: -1
# eg triggered at  1054
# arm
# 1.0     0.005481
# 4.0     1.000000
# 6.0     0.515443
# 7.0     1.000000
# 8.0     0.167251
# 11.0    0.101472
# 14.0    0.046487
# 17.0    0.000012
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1336
# Detected Sign: -1
# Detector cooling
# eg triggered at  1435
# arm
# 1.0     1.000000
# 4.0     0.700079
# 7.0     0.468008
# 10.0    0.973237
# 11.0    0.353824
# 14.0    0.178997
# 17.0    0.117268
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1507
# arm
# 1.0     1.000000
# 4.0     0.187087
# 7.0     0.473686
# 10.0    0.712071
# 11.0    0.057600
# 14.0    1.000000
# 17.0    0.433375
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 7 IDS_1 time: 60.06100034713745
# Reward change detected at time: 544
# Detected Sign: -1
# eg triggered at  544
# arm
# 1.0     0.376160
# 4.0     0.516297
# 6.0     0.534368
# 7.0     0.485974
# 11.0    0.701964
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 772
# Detected Sign: -1
# eg triggered at  796
# arm
# 1.0     0.014327
# 4.0     0.701588
# 5.0     0.255353
# 7.0     0.751668
# 11.0    0.036743
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1040
# arm
# 1.0     1.000000
# 4.0     0.452324
# 5.0     0.559914
# 6.0     0.331646
# 7.0     0.510715
# 11.0    0.405788
# 14.0    0.000053
# 17.0    0.026147
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1266
# Detected Sign: -1
# eg triggered at  1302
# arm
# 1.0     1.000000
# 4.0     0.404090
# 7.0     0.676573
# 10.0    0.618821
# 11.0    0.533183
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1336
# arm
# 1.0     0.000338
# 4.0     1.000000
# 7.0     0.677806
# 10.0    0.849144
# 11.0    1.000000
# 14.0    0.079119
# 17.0    0.019235
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 8 IDS_1 time: 109.22381901741028
# Reward change detected at time: 722
# Detected Sign: -1
# eg triggered at  764
# arm
# 1.0     1.000000
# 4.0     0.805235
# 5.0     0.687814
# 7.0     0.510191
# 8.0     0.732710
# 11.0    0.612727
# 14.0    0.168049
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  788
# arm
# 1.0     1.000000
# 4.0     0.302093
# 5.0     0.048350
# 7.0     0.039859
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1007
# Detected Sign: -1
# eg triggered at  1028
# arm
# 1.0     5.644596e-03
# 4.0     5.407076e-03
# 5.0     3.395214e-01
# 6.0     6.050061e-01
# 7.0     1.463510e-01
# 11.0    6.346944e-03
# 14.0    1.143632e-04
# 17.0    7.709316e-08
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1214
# Detected Sign: -1
# eg triggered at  1233
# arm
# 1.0     1.000000
# 4.0     0.700671
# 7.0     0.234924
# 11.0    0.776094
# 14.0    0.754309
# 17.0    0.294610
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1317
# arm
# 1.0     0.613804
# 4.0     1.000000
# 7.0     0.450455
# 11.0    0.152863
# 14.0    0.754275
# 17.0    0.056320
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1479
# Detected Sign: -1
# eg triggered at  1513
# arm
# 1.0     0.613855
# 4.0     0.225323
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    0.291598
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1559
# arm
# 1.0     1.000000
# 4.0     0.225324
# 7.0     1.000000
# 11.0    0.415543
# 14.0    0.345498
# 17.0    0.015980
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1814
# arm
# 1.0     0.613795
# 4.0     0.225307
# 7.0     0.133816
# 11.0    0.757229
# 14.0    0.345543
# 17.0    0.000685
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDS_1 time: 109.04779314994812

# %%
#IDST_1
IDST_1_df = pd.DataFrame()
IDST_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDST_1 = IDS_theta_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDST_1_sum, IDST_1_pt, IDST_1_re, IDST_1_arm, IDST_1_post = IDST_1.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDST_1 time:',end-start)
    exp_MAB_1.reset_t()
    IDST_1_df = IDST_1_df.append([np.cumsum(IDST_1_re)])
    IDST_1_df_arm = IDST_1_df_arm.append([IDST_1_arm])
# Out:
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# eg triggered at  1111
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.301930
# 6.0     0.380655
# 7.0     0.000867
# 8.0     0.771226
# 11.0    0.076469
# 14.0    0.064294
# 17.0    0.303523
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1473
# Detected Sign: -1
# eg triggered at  1534
# arm
# 1.0     0.066715
# 4.0     0.223336
# 7.0     1.000000
# 11.0    1.000000
# 12.0    0.871199
# 14.0    0.760894
# 17.0    0.456196
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1766
# arm
# 1.0     1.000000
# 4.0     0.054039
# 7.0     0.409752
# 11.0    0.203275
# 12.0    0.420682
# 13.0    0.667781
# 14.0    1.000000
# 17.0    0.042133
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 0 IDST_1 time: 81.1905951499939
# Reward change detected at time: 781
# Detected Sign: -1
# Detector cooling
# eg triggered at  809
# arm
# 1.0     0.503824
# 4.0     0.837201
# 5.0     0.403915
# 6.0     0.060095
# 7.0     0.181203
# 11.0    0.024710
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# eg triggered at  1087
# arm
# 1.0     8.459296e-03
# 4.0     1.020738e-01
# 5.0     1.000000e+00
# 6.0     7.671204e-01
# 7.0     1.272580e-01
# 8.0     7.541198e-01
# 11.0    3.058103e-01
# 14.0    3.591621e-02
# 17.0    1.361174e-08
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1904
# Detected Sign: -1
# eg triggered at  1913
# arm
# 1.0     0.005498
# 4.0     0.027753
# 7.0     1.000000
# 11.0    0.201463
# 12.0    1.000000
# 14.0    0.761039
# 17.0    0.013304
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 1 IDST_1 time: 121.49897503852844
# Reward change detected at time: 569
# Detected Sign: -1
# eg triggered at  597
# arm
# 1.0     0.585624
# 4.0     1.000000
# 5.0     0.131565
# 6.0     0.849037
# 7.0     0.751498
# 9.0     0.839055
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  650
# arm
# 1.0     1.000000
# 4.0     0.032041
# 5.0     0.087976
# 6.0     1.000000
# 7.0     0.053248
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  694
# arm
# 1.0     1.000000
# 4.0     0.736848
# 5.0     0.431253
# 7.0     0.750739
# 11.0    0.378751
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 1005
# Detected Sign: -1
# eg triggered at  1045
# arm
# 1.0     1.000000
# 4.0     0.196622
# 6.0     0.011961
# 7.0     0.418909
# 8.0     0.950234
# 11.0    0.026305
# 14.0    0.234048
# 17.0    0.370532
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1070
# arm
# 1.0     0.005481
# 4.0     0.194748
# 7.0     0.021942
# 8.0     0.283990
# 11.0    0.117346
# 14.0    0.448303
# 17.0    0.001696
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1474
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1486
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     1.000000
# 11.0    0.749486
# 12.0    0.859659
# 14.0    1.000000
# 17.0    0.020994
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1664
# arm
# 1.0     0.121226
# 4.0     0.150249
# 7.0     0.138328
# 11.0    0.214980
# 12.0    0.715389
# 14.0    1.000000
# 17.0    0.004522
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDST_1 time: 131.9391622543335
# Reward change detected at time: 1002
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1030
# arm
# 1.0     1.000000
# 4.0     0.184008
# 6.0     0.188734
# 7.0     0.819021
# 11.0    0.072624
# 14.0    0.000202
# 17.0    0.001490
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1509
# Detected Sign: -1
# eg triggered at  1582
# arm
# 1.0     0.005695
# 4.0     0.593596
# 7.0     0.700795
# 11.0    0.821421
# 13.0    0.546224
# 14.0    0.316884
# 17.0    0.474683
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 3 IDST_1 time: 110.39221501350403
# Reward change detected at time: 259
# Detected Sign: -1
# Detector cooling
# eg triggered at  319
# arm
# 1.0     0.035177
# 4.0     1.000000
# 5.0     0.069707
# 6.0     0.025681
# 7.0     0.749182
# 11.0    0.613723
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 479
# Detected Sign: -1
# eg triggered at  494
# arm
# 1.0     1.000000
# 4.0     0.495268
# 5.0     0.131565
# 6.0     0.221978
# 7.0     0.535080
# 11.0    0.614064
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  782
# arm
# 1.0     1.000000
# 4.0     0.733388
# 5.0     0.063862
# 7.0     0.216981
# 11.0    0.614426
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1007
# Detected Sign: 1
# Detector cooling
# eg triggered at  1032
# arm
# 1.0     0.008532
# 4.0     0.105088
# 5.0     0.723739
# 6.0     0.198036
# 7.0     0.348640
# 11.0    0.330694
# 14.0    0.106739
# 17.0    0.112820
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1203
# arm
# 1.0     0.008460
# 4.0     0.439733
# 7.0     0.000181
# 8.0     0.836516
# 11.0    0.104850
# 14.0    0.105778
# 17.0    0.022753
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1579
# Detected Sign: -1
# eg triggered at  1602
# arm
# 1.0     0.046705
# 4.0     0.622117
# 7.0     0.687798
# 9.0     0.321578
# 11.0    0.050807
# 14.0    0.183086
# 17.0    0.655128
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1629
# arm
# 1.0     1.000000
# 4.0     0.622082
# 7.0     1.000000
# 9.0     0.325404
# 11.0    0.527650
# 14.0    1.000000
# 17.0    0.107896
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 4 IDST_1 time: 129.20830702781677
# Reward change detected at time: 309
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  351
# arm
# 1.0     1.000000
# 4.0     0.733215
# 5.0     0.110860
# 6.0     1.000000
# 7.0     1.000000
# 11.0    0.612618
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  415
# arm
# 1.0     0.348215
# 4.0     0.733218
# 5.0     0.018956
# 7.0     0.745422
# 11.0    0.258657
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1006
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1035
# arm
# 1.0     0.008462
# 4.0     0.049631
# 5.0     1.000000
# 6.0     0.634034
# 7.0     1.000000
# 11.0    0.472994
# 14.0    0.276424
# 17.0    0.000040
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1351
# Detected Sign: -1
# eg triggered at  1367
# arm
# 1.0     0.136868
# 4.0     0.684804
# 7.0     0.259494
# 10.0    0.224859
# 11.0    0.346189
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1428
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.261410
# 10.0    0.178861
# 11.0    0.050469
# 14.0    0.738141
# 17.0    0.757995
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1833
# arm
# 1.0     1.000000
# 4.0     0.394233
# 7.0     1.000000
# 10.0    0.907122
# 11.0    1.000000
# 14.0    0.316158
# 17.0    0.116167
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 5 IDST_1 time: 109.21601271629333
# Reward change detected at time: 1026
# Detected Sign: 1
# eg triggered at  1051
# arm
# 1.0     1.000000
# 4.0     0.119844
# 7.0     0.766787
# 8.0     0.442508
# 9.0     0.616184
# 11.0    1.000000
# 14.0    0.120188
# 17.0    0.001812
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1431
# Detected Sign: 1
# Detector cooling
# eg triggered at  1451
# arm
# 1.0     0.025376
# 4.0     0.605147
# 7.0     0.000976
# 10.0    0.512216
# 11.0    0.536949
# 14.0    1.000000
# 17.0    0.736487
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1781
# Detected Sign: -1
# eg triggered at  1781
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.737693
# 11.0    0.356448
# 14.0    0.655882
# 17.0    0.017508
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1883
# Detected Sign: -1
# eg triggered at  1943
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.375185
# 8.0     1.000000
# 9.0     0.843632
# 11.0    1.000000
# 14.0    0.286199
# 17.0    0.514998
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 6 IDST_1 time: 138.74021410942078
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1025
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1038
# arm
# 1.0     1.000000
# 4.0     0.301759
# 6.0     0.362557
# 7.0     0.385063
# 11.0    0.055875
# 14.0    0.419243
# 17.0    0.013793
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1060
# arm
# 1.0     0.005983
# 4.0     0.303225
# 6.0     0.105817
# 7.0     1.000000
# 11.0    0.204082
# 14.0    0.418515
# 17.0    0.000004
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 7 IDST_1 time: 85.18144607543945
# Reward change detected at time: 161
# Detected Sign: -1
# eg triggered at  204
# arm
# 1.0     0.622960
# 4.0     0.725094
# 5.0     0.163929
# 6.0     0.750712
# 7.0     0.185973
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  258
# arm
# 1.0     0.356127
# 4.0     0.546750
# 7.0     0.077505
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  430
# arm
# 1.0     1.000000
# 4.0     0.149259
# 7.0     1.000000
# 11.0    0.614005
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# arm
# 4.0     2.220545e-187
# 5.0      1.000000e+00
# 6.0      6.980120e-01
# 7.0      7.777820e-01
# 17.0     1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1742
# Detected Sign: -1
# eg triggered at  1762
# arm
# 1.0     1.000000
# 4.0     0.343495
# 7.0     1.000000
# 11.0    0.057213
# 12.0    0.626514
# 14.0    0.534971
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1850
# arm
# 1.0     1.000000
# 4.0     0.622252
# 7.0     0.233809
# 11.0    0.208265
# 12.0    0.503916
# 14.0    0.749188
# 17.0    0.777198
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  1991
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.446411
# 11.0    0.749272
# 12.0    0.783931
# 14.0    0.533061
# 17.0    0.778208
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 8 IDST_1 time: 105.98217487335205
# Reward change detected at time: 845
# Detected Sign: -1
# eg triggered at  923
# arm
# 1.0     1.000000
# 4.0     0.015264
# 5.0     0.929480
# 6.0     0.101574
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  966
# arm
# 1.0     1.000000
# 4.0     0.735448
# 5.0     0.015633
# 7.0     0.749419
# 11.0    0.142918
# 14.0    1.000000
# 17.0    0.012907
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# arm
# 5.0     3.085782e-35
# 6.0     3.553896e-02
# 7.0     7.874487e-01
# 17.0    2.895263e-01
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1339
# Detected Sign: -1
# eg triggered at  1339
# arm
# 1.0     0.263472
# 4.0     0.225393
# 7.0     0.723279
# 10.0    0.752857
# 11.0    1.000000
# 14.0    0.186377
# 17.0    0.102954
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1396
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.468182
# 10.0    0.610959
# 11.0    0.750298
# 14.0    1.000000
# 17.0    0.038655
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 9 IDST_1 time: 104.73361706733704

# %%
#IDS_2 L=4 n=1
IDS_2_df = pd.DataFrame()
IDS_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_2 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=2,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_2_sum, IDS_2_pt, IDS_2_re, IDS_2_arm, IDS_2_post = IDS_2.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_2 time:',end-start)
    IDS_2_df = IDS_2_df.append([np.cumsum(IDS_2_re)])
    IDS_2_df_arm = IDS_2_df_arm.append([IDS_2_arm])
    
#IDS_3 L=2 n=2
IDS_3_df = pd.DataFrame()
IDS_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDS_3 = IDS_pull(price_list=price_list, N=update_freq+1, start_L=2, update_L=2,
                     simulate_time_initiate=2, simulate_time_update=1, window_width=100, eg_p=0.1)
    IDS_3_sum, IDS_3_pt, IDS_3_re, IDS_3_arm, IDS_3_post = IDS_3.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDS_3 time:',end-start)
    IDS_3_df = IDS_3_df.append([np.cumsum(IDS_3_re)])
    IDS_3_df_arm = IDS_3_df_arm.append([IDS_3_arm])
# Out:
# Reward change detected at time: 176
# Detected Sign: -1
# eg triggered at  198
# arm
# 1.0     1.000000
# 3.0     0.640880
# 4.0     0.713871
# 5.0     0.775142
# 7.0     0.528810
# 8.0     0.017353
# 11.0    1.000000
# 14.0    0.092505
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  239
# arm
# 1.0     1.000000
# 4.0     0.066116
# 5.0     0.470487
# 7.0     0.757336
# 11.0    0.618254
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  568
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.073120
# 7.0     1.000000
# 11.0    0.022049
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 709
# Detected Sign: -1
# Detector cooling
# eg triggered at  726
# arm
# 1.0     0.384573
# 4.0     0.070376
# 5.0     0.233493
# 6.0     0.206784
# 7.0     1.000000
# 11.0    1.000000
# 14.0    0.094451
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  865
# arm
# 1.0     1.000000
# 4.0     0.711010
# 5.0     0.476319
# 7.0     1.000000
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1010
# Detected Sign: 1
# eg triggered at  1029
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.376669
# 7.0     0.928654
# 8.0     0.318728
# 10.0    1.000000
# 11.0    1.000000
# 14.0    0.008474
# 17.0    0.000909
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1225
# Detected Sign: 1
# eg triggered at  1619
# arm
# 1.0     0.297792
# 4.0     1.000000
# 7.0     1.000000
# 10.0    0.020439
# 11.0    0.749178
# 14.0    0.512214
# 17.0    0.000004
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1834
# Detected Sign: -1
# eg triggered at  1847
# arm
# 1.0     0.129094
# 4.0     0.375870
# 7.0     1.000000
# 11.0    0.341272
# 12.0    0.391635
# 14.0    1.000000
# 17.0    0.225633
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 0 IDS_2 time: 123.66986393928528
# Reward change detected at time: 224
# Detected Sign: -1
# eg triggered at  266
# arm
# 1.0     1.000000
# 4.0     0.291988
# 5.0     0.364490
# 6.0     1.000000
# 7.0     0.510880
# 11.0    0.583114
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  367
# arm
# 1.0     0.085231
# 4.0     0.073851
# 5.0     0.568954
# 7.0     0.343685
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1002
# Detected Sign: 1
# Detector cooling
# eg triggered at  1034
# arm
# 1.0     1.000000
# 4.0     0.366283
# 5.0     0.118499
# 6.0     0.676791
# 7.0     0.396141
# 11.0    0.138479
# 14.0    0.009032
# 17.0    0.168969
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1048
# arm
# 1.0     1.000000
# 4.0     0.366328
# 7.0     1.000000
# 11.0    0.023065
# 14.0    0.054879
# 17.0    0.005560
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1223
# Detected Sign: -1
# Detector cooling
# eg triggered at  1233
# arm
# 1.0     1.000000
# 4.0     0.157037
# 7.0     1.000000
# 11.0    0.750725
# 12.0    0.562743
# 14.0    0.205846
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1274
# arm
# 1.0     0.352303
# 4.0     0.375708
# 7.0     0.130425
# 11.0    0.751173
# 12.0    0.588066
# 14.0    0.531278
# 17.0    0.762061
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1935
# Detected Sign: -1
# eg triggered at  1974
# arm
# 1.0     0.304603
# 4.0     0.376085
# 7.0     0.703441
# 11.0    0.523546
# 12.0    0.761294
# 14.0    0.529937
# 17.0    0.390413
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1986
# arm
# 1.0     1.000000
# 4.0     0.150479
# 7.0     0.130464
# 11.0    0.334588
# 12.0    0.694894
# 14.0    0.117462
# 17.0    0.136093
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 1 IDS_2 time: 88.13743185997009
# Reward change detected at time: 448
# Detected Sign: -1
# eg triggered at  484
# arm
# 1.0     0.260388
# 4.0     0.365416
# 5.0     0.179124
# 7.0     0.177110
# 11.0    0.160900
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  496
# arm
# 1.0     0.260380
# 4.0     0.468631
# 5.0     0.507173
# 7.0     0.333466
# 11.0    0.529306
# 14.0    0.175651
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 698
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  710
# arm
# 1.0     0.260726
# 4.0     0.673978
# 5.0     0.845250
# 7.0     1.000000
# 11.0    0.531162
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  763
# arm
# 1.0     0.260402
# 4.0     0.468622
# 5.0     0.235783
# 7.0     0.059195
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1024
# arm
# 1.0     1.000000
# 4.0     0.047968
# 5.0     0.016811
# 6.0     0.538539
# 7.0     0.195743
# 11.0    0.001438
# 14.0    0.556677
# 17.0    0.000645
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1364
# Detected Sign: 1
# Detector cooling
# Detector cooling
# eg triggered at  1401
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     1.000000
# 11.0    0.201493
# 12.0    0.673379
# 13.0    0.096123
# 14.0    0.016546
# 17.0    0.718463
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1543
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.699756
# 11.0    1.000000
# 12.0    0.778104
# 14.0    0.212335
# 17.0    0.109532
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1588
# Detected Sign: 1
# eg triggered at  1681
# arm
# 1.0     0.046013
# 4.0     0.214487
# 7.0     1.000000
# 9.0     0.822705
# 10.0    0.346902
# 11.0    0.060181
# 12.0    0.026265
# 13.0    0.943711
# 14.0    0.750949
# 17.0    0.720970
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1924
# arm
# 1.0     1.000000
# 4.0     0.510905
# 7.0     0.091341
# 9.0     0.249935
# 11.0    1.000000
# 13.0    0.027930
# 14.0    0.349704
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1972
# Detected Sign: -1
# eg triggered at  1979
# arm
# 1.0     1.000000
# 4.0     0.509932
# 7.0     1.000000
# 9.0     0.457612
# 11.0    0.528941
# 14.0    0.187562
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 2 IDS_2 time: 109.89293003082275
# trial 3 IDS_2 time: 7.063952207565308
# Reward change detected at time: 305
# Detected Sign: -1
# Detector cooling
# eg triggered at  415
# arm
# 1.0     1.000000
# 4.0     0.188693
# 5.0     0.001672
# 6.0     0.364463
# 7.0     0.185431
# 11.0    0.277044
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  1073
# arm
# 1.0     1.000000
# 4.0     0.129439
# 6.0     0.282014
# 7.0     0.076232
# 11.0    0.342226
# 14.0    0.677189
# 17.0    0.000808
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 4 IDS_2 time: 88.45246601104736
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# eg triggered at  1021
# arm
# 1.0     1.000000
# 4.0     0.612792
# 5.0     1.000000
# 6.0     0.853135
# 7.0     0.259930
# 11.0    0.000026
# 14.0    0.167519
# 17.0    0.000013
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1985
# Detected Sign: -1
# trial 5 IDS_2 time: 60.40762114524841
# Reward change detected at time: 584
# Detected Sign: -1
# Detector cooling
# eg triggered at  612
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.346352
# 7.0     0.750746
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  848
# arm
# 1.0     0.406250
# 4.0     1.000000
# 6.0     0.427980
# 7.0     1.000000
# 11.0    0.613658
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  922
# arm
# 1.0     0.406250
# 4.0     0.499166
# 6.0     0.466306
# 7.0     0.750802
# 11.0    0.292006
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 1002
# Detected Sign: -1
# eg triggered at  1056
# arm
# 1.0     0.006822
# 4.0     0.006677
# 7.0     0.210200
# 8.0     0.830567
# 9.0     0.496794
# 11.0    0.053405
# 14.0    0.650490
# 17.0    0.010227
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1118
# arm
# 1.0     1.000000
# 4.0     0.006674
# 7.0     0.572084
# 11.0    0.001280
# 14.0    0.000126
# 17.0    0.000261
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1294
# Detected Sign: -1
# eg triggered at  1305
# arm
# 1.0     1.000000
# 4.0     0.041740
# 7.0     0.217493
# 9.0     1.000000
# 11.0    0.581736
# 14.0    0.008838
# 17.0    0.008597
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1420
# arm
# 1.0     1.000000
# 4.0     0.006583
# 7.0     0.673440
# 9.0     0.794276
# 11.0    0.003409
# 14.0    0.194494
# 17.0    0.003897
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 6 IDS_2 time: 98.28062224388123
# Reward change detected at time: 535
# Detected Sign: -1
# eg triggered at  556
# arm
# 1.0     1.000000
# 4.0     0.698841
# 5.0     0.562583
# 7.0     0.203007
# 11.0    0.375825
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 863
# Detected Sign: 1
# eg triggered at  872
# arm
# 1.0     1.000000
# 4.0     0.428305
# 5.0     0.822948
# 7.0     0.333432
# 11.0    0.612670
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# arm
# 4.0     7.220716e-43
# 5.0     3.682421e-16
# 6.0     3.801698e-02
# 17.0    1.000000e+00
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1968
# Detected Sign: -1
# trial 7 IDS_2 time: 87.18928289413452
# Reward change detected at time: 632
# Detected Sign: 1
# eg triggered at  675
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     1.000000
# 6.0     0.222257
# 7.0     0.100726
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  963
# arm
# 1.0     1.000000
# 4.0     0.734619
# 5.0     0.055838
# 7.0     0.750570
# 11.0    0.265604
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# eg triggered at  1034
# arm
# 1.0     1.000000e+00
# 4.0     4.051218e-01
# 5.0     6.507859e-02
# 6.0     8.211701e-01
# 7.0     2.718907e-01
# 11.0    3.784280e-02
# 14.0    1.880639e-03
# 17.0    2.795303e-09
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1205
# Detected Sign: -1
# eg triggered at  1268
# arm
# 1.0     0.034863
# 4.0     1.000000
# 7.0     0.208217
# 11.0    0.191592
# 12.0    0.607771
# 13.0    0.435607
# 14.0    0.203242
# 17.0    0.142903
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1381
# arm
# 1.0     1.000000
# 4.0     0.572261
# 7.0     0.067016
# 11.0    1.000000
# 12.0    0.354091
# 14.0    0.362058
# 17.0    0.200771
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 8 IDS_2 time: 74.0304811000824
# Reward change detected at time: 447
# Detected Sign: 1
# eg triggered at  447
# arm
# 1.0     1.000000
# 4.0     0.733333
# 6.0     0.203344
# 7.0     0.123466
# 11.0    0.131284
# 14.0    0.548977
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  488
# arm
# 1.0     1.000000
# 4.0     0.299476
# 5.0     0.219216
# 6.0     0.502388
# 7.0     0.742464
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 830
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  869
# arm
# 1.0     0.026645
# 4.0     1.000000
# 5.0     0.477711
# 7.0     0.037678
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  945
# arm
# 1.0     1.000000
# 4.0     0.499496
# 5.0     0.003515
# 7.0     1.000000
# 11.0    0.144337
# 14.0    0.019378
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDS_2 time: 61.839213132858276
# Reward change detected at time: 562
# Detected Sign: -1
# Reward change detected at time: 628
# Detected Sign: -1
# eg triggered at  643
# arm
# 1.0     0.130126
# 4.0     0.733432
# 5.0     0.933238
# 6.0     0.536639
# 7.0     0.005975
# 11.0    0.142691
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 936
# Detected Sign: -1
# Detector cooling
# Detector cooling
# eg triggered at  944
# arm
# 1.0     0.136403
# 4.0     1.000000
# 5.0     0.828763
# 7.0     0.511446
# 11.0    0.495820
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1004
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1032
# arm
# 1.0     1.000000
# 4.0     0.013186
# 5.0     0.038467
# 6.0     0.628836
# 7.0     0.047737
# 8.0     0.542477
# 11.0    0.051209
# 14.0    0.007051
# 17.0    0.003975
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1752
# Detected Sign: -1
# Detector cooling
# eg triggered at  1826
# arm
# 1.0     1.000000
# 4.0     0.184732
# 7.0     0.130626
# 11.0    0.247995
# 14.0    0.104263
# 17.0    0.377704
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1863
# arm
# 1.0     1.000000
# 4.0     0.185670
# 7.0     0.474222
# 11.0    0.730545
# 14.0    0.336086
# 17.0    0.314893
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# trial 0 IDS_3 time: 124.38979291915894
# Reward change detected at time: 1005
# Detected Sign: -1
# Detector cooling
# eg triggered at  1031
# arm
# 1.0     1.000000
# 4.0     0.013448
# 5.0     0.440695
# 7.0     0.820572
# 8.0     0.668201
# 11.0    1.000000
# 14.0    0.024670
# 17.0    0.001572
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1571
# Detected Sign: -1
# Detector cooling
# eg triggered at  1679
# arm
# 1.0     0.006447
# 4.0     0.612921
# 7.0     1.000000
# 11.0    0.785025
# 12.0    0.018985
# 14.0    1.000000
# 17.0    0.012829
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 1 IDS_3 time: 83.94301009178162
# Reward change detected at time: 889
# Detected Sign: -1
# eg triggered at  918
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.273597
# 6.0     0.942068
# 7.0     1.000000
# 8.0     0.106913
# 11.0    0.612780
# 14.0    0.160572
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1003
# Detected Sign: 1
# Detector cooling
# eg triggered at  1082
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.615043
# 7.0     0.700137
# 9.0     0.174868
# 10.0    0.758618
# 11.0    0.529415
# 14.0    0.076418
# 17.0    0.069704
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1218
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.225605
# 9.0     0.000509
# 11.0    0.760166
# 14.0    0.017560
# 17.0    0.001513
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1429
# Detected Sign: -1
# eg triggered at  1450
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     1.000000
# 11.0    0.749506
# 12.0    0.891957
# 14.0    1.000000
# 17.0    0.009904
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1617
# arm
# 1.0     1.000000
# 4.0     0.468178
# 7.0     0.512452
# 11.0    0.211512
# 12.0    0.225507
# 13.0    0.826442
# 14.0    0.754064
# 17.0    0.000008
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 2 IDS_3 time: 95.65536904335022
# Reward change detected at time: 1019
# Detected Sign: 1
# eg triggered at  1070
# arm
# 1.0     0.007174
# 4.0     0.018695
# 5.0     0.015580
# 6.0     0.021928
# 7.0     0.682958
# 8.0     0.170722
# 11.0    0.525643
# 14.0    0.002748
# 17.0    0.000316
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1634
# Detected Sign: -1
# Detector cooling
# eg triggered at  1656
# arm
# 1.0     0.006459
# 4.0     0.120872
# 7.0     1.000000
# 11.0    1.000000
# 13.0    1.000000
# 14.0    0.589971
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 3 IDS_3 time: 82.66281318664551
# Reward change detected at time: 352
# Detected Sign: -1
# Detector cooling
# eg triggered at  406
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.772072
# 6.0     0.429060
# 7.0     0.652344
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 536
# Detected Sign: -1
# eg triggered at  536
# arm
# 1.0     1.000000
# 4.0     1.000000
# 6.0     0.208710
# 7.0     0.759927
# 11.0    0.645909
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  678
# arm
# 1.0     1.000000
# 4.0     0.489416
# 6.0     0.004303
# 7.0     0.527777
# 11.0    0.242855
# 14.0    0.080475
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1005
# Detected Sign: -1
# eg triggered at  1005
# arm
# 1.0     1.000000e+00
# 4.0     3.010709e-01
# 6.0     7.584086e-01
# 7.0     1.217893e-01
# 11.0    3.240624e-05
# 14.0    2.410072e-03
# 17.0    1.147368e-08
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 4 IDS_3 time: 101.24451398849487
# Reward change detected at time: 603
# Detected Sign: -1
# eg triggered at  657
# arm
# 1.0     1.000000
# 4.0     0.427731
# 5.0     0.602594
# 6.0     0.145177
# 7.0     0.753270
# 11.0    0.627445
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  841
# arm
# 1.0     0.485958
# 4.0     0.305526
# 5.0     0.228399
# 7.0     0.339912
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 888
# Detected Sign: 1
# eg triggered at  888
# arm
# 1.0     0.367780
# 4.0     0.733971
# 5.0     0.749381
# 7.0     0.209475
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1005
# Detected Sign: 1
# Detector cooling
# eg triggered at  1036
# arm
# 1.0     0.005484
# 4.0     0.000032
# 5.0     1.000000
# 7.0     0.878724
# 8.0     0.219015
# 10.0    0.533967
# 11.0    0.334235
# 14.0    1.000000
# 17.0    0.001705
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 5 IDS_3 time: 74.53442907333374
# Reward change detected at time: 444
# Detected Sign: -1
# Detector cooling
# eg triggered at  487
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.420694
# 7.0     1.000000
# 11.0    0.072482
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 578
# Detected Sign: -1
# eg triggered at  637
# arm
# 1.0     1.000000
# 4.0     0.300563
# 5.0     0.001297
# 7.0     0.746770
# 11.0    0.409975
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 980
# Detected Sign: -1
# eg triggered at  980
# arm
# 1.0     1.000000
# 4.0     0.516490
# 5.0     0.753113
# 7.0     0.335793
# 11.0    1.000000
# 14.0    0.235986
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1009
# Detected Sign: 1
# eg triggered at  1030
# arm
# 1.0     1.000000
# 4.0     0.388774
# 6.0     0.795926
# 7.0     0.772725
# 11.0    0.008599
# 14.0    0.000105
# 17.0    0.000484
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1714
# Detected Sign: -1
# Detector cooling
# eg triggered at  1721
# arm
# 1.0     0.100176
# 4.0     1.000000
# 7.0     0.255672
# 11.0    0.333452
# 14.0    0.833204
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1815
# arm
# 1.0     1.000000
# 4.0     0.376168
# 7.0     0.470588
# 11.0    0.333452
# 14.0    0.070210
# 17.0    0.442224
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1842
# Detected Sign: 1
# eg triggered at  1869
# arm
# 1.0     0.098885
# 4.0     0.636863
# 7.0     0.255470
# 11.0    0.749260
# 14.0    0.240204
# 17.0    0.064190
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1919
# Detected Sign: -1
# eg triggered at  1919
# arm
# 1.0     0.177875
# 4.0     0.642776
# 7.0     1.000000
# 11.0    0.749270
# 14.0    1.000000
# 17.0    0.710579
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 6 IDS_3 time: 148.49872016906738
# Reward change detected at time: 1026
# Detected Sign: 1
# eg triggered at  1183
# arm
# 1.0     1.000000
# 4.0     0.096823
# 5.0     0.032544
# 7.0     0.574967
# 8.0     0.002116
# 11.0    1.000000
# 14.0    0.000356
# 17.0    0.000187
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1810
# Detected Sign: -1
# eg triggered at  1836
# arm
# 1.0     0.013642
# 4.0     0.623089
# 7.0     0.241607
# 11.0    0.269929
# 14.0    0.038481
# 17.0    0.673284
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# Reward change detected at time: 1932
# Detected Sign: -1
# eg triggered at  1947
# arm
# 1.0     1.000000
# 4.0     0.357296
# 7.0     1.000000
# 11.0    0.694392
# 14.0    1.000000
# 17.0    0.216240
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# trial 7 IDS_3 time: 71.69806218147278
# Reward change detected at time: 727
# Detected Sign: 1
# eg triggered at  745
# arm
# 1.0     1.000000
# 4.0     1.000000
# 5.0     0.765314
# 7.0     0.529906
# 11.0    0.320674
# 14.0    0.443149
# 17.0    0.033217
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  956
# arm
# 1.0     0.539769
# 4.0     0.732893
# 5.0     0.400287
# 7.0     1.000000
# 11.0    0.616691
# 14.0    1.000000
# 17.0    0.064841
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1008
# Detected Sign: 1
# Detector cooling
# eg triggered at  1046
# arm
# 1.0     1.000000e+00
# 4.0     4.441550e-01
# 5.0     6.134096e-01
# 7.0     1.498619e-01
# 8.0     4.192940e-01
# 9.0     2.725962e-01
# 10.0    1.039000e-01
# 11.0    3.071863e-01
# 14.0    2.062436e-09
# 17.0    4.456082e-01
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1549
# Detected Sign: -1
# eg triggered at  1560
# arm
# 1.0     1.000000
# 4.0     0.044899
# 7.0     0.468011
# 11.0    0.856486
# 14.0    0.755683
# 17.0    0.651026
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1590
# arm
# 1.0     1.000000
# 4.0     0.585197
# 7.0     0.133340
# 11.0    0.514594
# 14.0    0.184155
# 17.0    0.203613
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1757
# Detected Sign: -1
# eg triggered at  1762
# arm
# 1.0     1.000000
# 4.0     1.000000
# 7.0     0.468534
# 11.0    0.324691
# 14.0    0.045177
# 17.0    0.655749
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1790
# arm
# 1.0     0.014590
# 4.0     0.190656
# 7.0     1.000000
# 11.0    0.276113
# 14.0    0.513305
# 17.0    0.528227
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Detector cooling
# Detector cooling
# Detector cooling
# eg triggered at  1942
# arm
# 1.0     1.000000
# 4.0     0.553471
# 7.0     0.710017
# 11.0    0.125066
# 14.0    0.753488
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# trial 8 IDS_3 time: 84.32089114189148
# Reward change detected at time: 317
# Detected Sign: -1
# eg triggered at  325
# arm
# 1.0     1.000000
# 4.0     0.547405
# 6.0     0.753214
# 7.0     1.000000
# 11.0    0.431678
# 14.0    0.020179
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  373
# arm
# 1.0     0.054810
# 4.0     0.034037
# 7.0     0.341525
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# eg triggered at  425
# arm
# 1.0     1.000000
# 4.0     0.156504
# 7.0     0.108836
# 11.0    1.000000
# 14.0    1.000000
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.0001
# Reward change detected at time: 1006
# Detected Sign: -1
# Detector cooling
# eg triggered at  1021
# arm
# 1.0     1.000000
# 4.0     0.417228
# 5.0     0.147118
# 6.0     0.163614
# 7.0     0.208571
# 11.0    0.051178
# 14.0    0.005360
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# Reward change detected at time: 1175
# Detected Sign: -1
# Detector cooling
# eg triggered at  1207
# arm
# 1.0     1.000000
# 4.0     0.411302
# 7.0     0.241633
# 10.0    0.730778
# 11.0    0.532660
# 14.0    0.105249
# 17.0    1.000000
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.010000000000000002
# eg triggered at  1226
# arm
# 1.0     0.018950
# 4.0     0.014069
# 7.0     0.702390
# 10.0    0.523451
# 11.0    0.204670
# 14.0    0.539947
# 17.0    0.426813
# Name: pvalue, dtype: float64
# tested non-significant , eg_p decayed to 0.001
# Reward change detected at time: 1388
# Detected Sign: 1
# eg triggered at  1400
# arm
# 1.0     1.000000
# 4.0     0.377113
# 7.0     1.000000
# 10.0    1.000000
# 11.0    0.751927
# 14.0    0.002039
# 17.0    1.000000
# Name: pvalue, dtype: float64
# demand shape does not match
# trial 9 IDS_3 time: 109.88072609901428

# %%
#IDS without transferability test
IDSN_df = pd.DataFrame()
IDSN_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDSN = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDSN_sum, IDSN_pt, IDSN_re, IDSN_arm, IDSN_post = IDSN.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDSN time:',end-start)
    IDSN_df = IDSN_df.append([np.cumsum(IDSN_re)])
    IDSN_df_arm = IDSN_df_arm.append([IDSN_arm])
    
#IDS with window likelihood
IDSW_df = pd.DataFrame()
IDSW_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    IDSW = IDS_pull(price_list=price_list, N=update_freq+1, start_L=4, update_L=0, update_during_exploit=True,
                     simulate_time_initiate=1, simulate_time_update=1, window_width=100, eg_p=0)
    IDSW_sum, IDSW_pt, IDSW_re, IDSW_arm, IDSW_post = IDSW.IDS(T=T, pricing_MAB=exp_MAB_1, mode='mode1',
                                                                     update_style='none', base=1000, p=np.nan,
                                                                     p_y=np.nan, R=np.nan)
    end = time.time()
    print('trial',i, 'IDSW time:',end-start)
    IDSW_df = IDSW_df.append([np.cumsum(IDSW_re)])
    IDSW_df_arm = IDSW_df_arm.append([IDSW_arm])
# Out:
# Reward change detected at time: 1554
# Detected Sign: 1
# Reward change detected at time: 1876
# Detected Sign: 1
# trial 0 IDSN time: 32.09074306488037
# Reward change detected at time: 426
# Detected Sign: -1
# Reward change detected at time: 631
# Detected Sign: 1
# Detector cooling
# Detector cooling
# Reward change detected at time: 798
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1004
# Detected Sign: -1
# Detector cooling
# Detector cooling
# trial 1 IDSN time: 61.95343279838562
# Reward change detected at time: 578
# Detected Sign: -1
# Reward change detected at time: 834
# Detected Sign: -1
# Reward change detected at time: 1011
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1267
# Detected Sign: 1
# Reward change detected at time: 1851
# Detected Sign: 1
# trial 2 IDSN time: 71.88767004013062
# Reward change detected at time: 327
# Detected Sign: -1
# Reward change detected at time: 711
# Detected Sign: -1
# Reward change detected at time: 907
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1002
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# Reward change detected at time: 1925
# Detected Sign: -1
# trial 3 IDSN time: 72.43899202346802
# Reward change detected at time: 556
# Detected Sign: 1
# Reward change detected at time: 1014
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1821
# Detected Sign: -1
# trial 4 IDSN time: 47.17754006385803
# Reward change detected at time: 427
# Detected Sign: -1
# trial 5 IDSN time: 22.90933609008789
# Reward change detected at time: 1003
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Detector cooling
# trial 6 IDSN time: 21.482680082321167
# Reward change detected at time: 206
# Detected Sign: -1
# Reward change detected at time: 712
# Detected Sign: -1
# Detector cooling
# Detector cooling
# Reward change detected at time: 742
# Detected Sign: -1
# Reward change detected at time: 818
# Detected Sign: -1
# Reward change detected at time: 1003
# Detected Sign: -1
# Detector cooling
# trial 7 IDSN time: 74.11411190032959
# trial 8 IDSN time: 7.724613904953003
# Reward change detected at time: 699
# Detected Sign: -1
# Detector cooling
# Reward change detected at time: 1008
# Detected Sign: 1
# Detector cooling
# Reward change detected at time: 1462
# Detected Sign: -1
# trial 9 IDSN time: 47.774394035339355
# trial 0 IDSW time: 113.55663895606995
# trial 1 IDSW time: 113.72721815109253
# trial 2 IDSW time: 113.27289295196533
# trial 3 IDSW time: 113.00938391685486
# trial 4 IDSW time: 113.2791497707367
# trial 5 IDSW time: 113.08375883102417
# trial 6 IDSW time: 113.1395890712738
# trial 7 IDSW time: 113.59213972091675
# trial 8 IDSW time: 112.95824098587036
# trial 9 IDSW time: 112.99676704406738

# %%
# UCB1 c=1
UCB_1_df = pd.DataFrame()
UCB_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=1, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_1 time:',end-start)
    UCB_1_df = UCB_1_df.append([np.cumsum(UCB1_re)])
    UCB_1_df_arm = UCB_1_df_arm.append([UCB1_arm])

# UCB1 c=2
UCB_2_df = pd.DataFrame()
UCB_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=False)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB_2 time:',end-start)
    UCB_2_df = UCB_2_df.append([np.cumsum(UCB1_re)])
    UCB_2_df_arm = UCB_2_df_arm.append([UCB1_arm])
    

# UCB-tuned
UCBT_df = pd.DataFrame()
UCBT_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCB1 = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=True, tuned=True)
    UCB1_sum, UCB1_pt, UCB1_re, UCB1_arm = UCB1.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCB-tuned time:',end-start)
    UCBT_df = UCBT_df.append([np.cumsum(UCB1_re)])
    UCBT_df_arm = UCBT_df_arm.append([UCB1_arm])
    
# UCBPI
UCBPI_df = pd.DataFrame()
UCBPI_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    UCBPI = UCBPI_pull(price_list=price_list, segments=segments, c=2, bias=0, UCB1=False, tuned=True)
    UCBPI_sum, UCBPI_pt, UCBPI_re, UCBPI_arm = UCBPI.UCBPI(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'UCBPI time:',end-start)
    UCBPI_df = UCBPI_df.append([np.cumsum(UCBPI_re)])
    UCBPI_df_arm = UCBPI_df_arm.append([UCBPI_arm])
    
# TS
TS_df = pd.DataFrame()
TS_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    TS = TS_pull(price_list=price_list, est='MEAN')
    TS_sum, TS_pt, TS_re, TS_arm = TS.TS(T=T, pricing_MAB=exp_MAB_1)
    end = time.time()
    print('trial',i, 'TS time:',end-start)
    TS_df = TS_df.append([np.cumsum(TS_re)])
    TS_df_arm = TS_df_arm.append([TS_arm])

# EG e=0.05
EG_1_df = pd.DataFrame()
EG_1_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.05)
    end = time.time()
    print('trial',i, 'EG 0.05 time:',end-start)
    EG_1_df = EG_1_df.append([np.cumsum(EG_re)])
    EG_1_df_arm = EG_1_df_arm.append([EG_arm])

# EG p=0.1
EG_2_df = pd.DataFrame()
EG_2_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.1)
    end = time.time()
    print('trial',i, 'EG 0.1 time:',end-start)
    EG_2_df = EG_2_df.append([np.cumsum(EG_re)])
    EG_2_df_arm = EG_2_df_arm.append([EG_arm])
    
# EG e=0.15
EG_3_df = pd.DataFrame()
EG_3_df_arm = pd.DataFrame()
for i in range(trial_rounds):
    start = time.time()
    EG = EG_pull(price_list=price_list)
    EG_sum, EG_pt, EG_re, EG_arm = EG.EG(T=T, pricing_MAB=exp_MAB_1, e=0.15)
    end = time.time()
    print('trial',i, 'EG 0.15 time:',end-start)
    EG_3_df = EG_3_df.append([np.cumsum(EG_re)])
    EG_3_df_arm = EG_3_df_arm.append([EG_arm])
# Out:
# trial 0 UCB_1 time: 0.7218239307403564
# trial 1 UCB_1 time: 0.718195915222168
# trial 2 UCB_1 time: 0.7209179401397705
# trial 3 UCB_1 time: 0.718757152557373
# trial 4 UCB_1 time: 0.7219600677490234
# trial 5 UCB_1 time: 0.7178099155426025
# trial 6 UCB_1 time: 0.7192869186401367
# trial 7 UCB_1 time: 0.7202959060668945
# trial 8 UCB_1 time: 0.7182211875915527
# trial 9 UCB_1 time: 0.7208502292633057
# trial 0 UCB_2 time: 0.7210018634796143
# trial 1 UCB_2 time: 0.7213408946990967
# trial 2 UCB_2 time: 0.7170512676239014
# trial 3 UCB_2 time: 0.7200682163238525
# trial 4 UCB_2 time: 0.7182478904724121
# trial 5 UCB_2 time: 0.7219338417053223
# trial 6 UCB_2 time: 0.7195169925689697
# trial 7 UCB_2 time: 0.7170858383178711
# trial 8 UCB_2 time: 0.7202999591827393
# trial 9 UCB_2 time: 0.719062089920044
# trial 0 UCB-tuned time: 1.3798720836639404
# trial 1 UCB-tuned time: 1.3784539699554443
# trial 2 UCB-tuned time: 1.347221851348877
# trial 3 UCB-tuned time: 1.4688870906829834
# trial 4 UCB-tuned time: 1.33394193649292
# trial 5 UCB-tuned time: 1.3781499862670898
# trial 6 UCB-tuned time: 1.375967025756836
# trial 7 UCB-tuned time: 1.4097342491149902
# trial 8 UCB-tuned time: 1.359496831893921
# trial 9 UCB-tuned time: 1.383768081665039
# trial 0 UCBPI time: 0.9120049476623535
# trial 1 UCBPI time: 1.2110750675201416
# trial 2 UCBPI time: 0.9122998714447021
# trial 3 UCBPI time: 0.915334939956665
# trial 4 UCBPI time: 0.9130239486694336
# trial 5 UCBPI time: 0.9113550186157227
# trial 6 UCBPI time: 0.9109587669372559
# trial 7 UCBPI time: 1.1775848865509033
# trial 8 UCBPI time: 0.9126558303833008
# trial 9 UCBPI time: 1.209434986114502
# trial 0 TS time: 1.494913101196289
# trial 1 TS time: 1.4840142726898193
# trial 2 TS time: 1.483422040939331
# trial 3 TS time: 1.4924910068511963
# trial 4 TS time: 1.4939088821411133
# trial 5 TS time: 1.4898371696472168
# trial 6 TS time: 1.4932870864868164
# trial 7 TS time: 1.4879279136657715
# trial 8 TS time: 1.4877707958221436
# trial 9 TS time: 1.4870941638946533
# trial 0 EG 0.05 time: 0.13492202758789062
# trial 1 EG 0.05 time: 0.13500523567199707
# trial 2 EG 0.05 time: 0.13571882247924805
# trial 3 EG 0.05 time: 0.13466596603393555
# trial 4 EG 0.05 time: 0.13452887535095215
# trial 5 EG 0.05 time: 0.13419699668884277
# trial 6 EG 0.05 time: 0.13508319854736328
# trial 7 EG 0.05 time: 0.1339890956878662
# trial 8 EG 0.05 time: 0.1332077980041504
# trial 9 EG 0.05 time: 0.13458681106567383
# trial 0 EG 0.1 time: 0.13398504257202148
# trial 1 EG 0.1 time: 0.13480305671691895
# trial 2 EG 0.1 time: 0.13486909866333008
# trial 3 EG 0.1 time: 0.13461565971374512
# trial 4 EG 0.1 time: 0.13425421714782715
# trial 5 EG 0.1 time: 0.13429474830627441
# trial 6 EG 0.1 time: 0.13416409492492676
# trial 7 EG 0.1 time: 0.13405704498291016
# trial 8 EG 0.1 time: 0.1334078311920166
# trial 9 EG 0.1 time: 0.13406705856323242
# trial 0 EG 0.15 time: 0.13338208198547363
# trial 1 EG 0.15 time: 0.13361191749572754
# trial 2 EG 0.15 time: 0.1330568790435791
# trial 3 EG 0.15 time: 0.1333632469177246
# trial 4 EG 0.15 time: 0.13586211204528809
# trial 5 EG 0.15 time: 0.1351337432861328
# trial 6 EG 0.15 time: 0.1346433162689209
# trial 7 EG 0.15 time: 0.13403987884521484
# trial 8 EG 0.15 time: 0.13440299034118652
# trial 9 EG 0.15 time: 0.13442420959472656

# %%
IDS_1_df = IDS_1_df.iloc[:,:2000]
IDS_2_df = IDS_2_df.iloc[:,:2000]
IDS_3_df = IDS_3_df.iloc[:,:2000]
IDST_1_df = IDST_1_df.iloc[:,:2000]
IDSN_df = IDSTN_df.iloc[:,:2000]
IDSW_df = IDSTW_df.iloc[:,:2000]
IDS_1_df_arm = IDS_1_df_arm.iloc[:,:2000]
IDS_2_df_arm = IDS_2_df_arm.iloc[:,:2000]
IDS_3_df_arm = IDS_3_df_arm.iloc[:,:2000]
IDST_1_df_arm = IDST_1_df_arm.iloc[:,:2000]
IDSN_df_arm = IDSN_df_arm.iloc[:,:2000]
IDSW_df_arm = IDSW_df_arm.iloc[:,:2000]

# %%
optimal_reward_per = pd.DataFrame(np.append(np.repeat(max(df1.groupby('arm')['reward'].mean()), T/2),
                              np.repeat(max(df2.groupby('arm')['reward'].mean()), T/2))).T
optimal_reward = optimal_reward_per.cumsum(axis=1)

# %%
def get_low(optimal_reward, df):
    return (optimal_reward - df.max()).values[0]
def get_high(optimal_reward, df):
    return (optimal_reward - df.min()).values[0]

# %%
def draw_regret(optimal_reward, IDS_1, IDS_2, IDS_3, IDST_1, IDSN, IDSW, UCB_1, UCB_2, UCBT, UCBPI, TS, EG_1, EG_2, EG_3, title, bounds=True):
    
    IDS_1_mean = (optimal_reward - IDS_1.mean()).values[0]
    IDS_2_mean = (optimal_reward - IDS_2.mean()).values[0]
    IDS_3_mean = (optimal_reward - IDS_3.mean()).values[0]
    IDST_1_mean = (optimal_reward - IDST_1.mean()).values[0]
    IDSN_mean = (optimal_reward - IDSN.mean()).values[0]
    IDSW_mean = (optimal_reward - IDSW.mean()).values[0]
    UCB_1_mean = (optimal_reward - UCB_1.mean()).values[0]
    UCB_2_mean = (optimal_reward - UCB_2.mean()).values[0]
    UCBT_mean = (optimal_reward - UCBT.mean()).values[0]
    UCBPI_mean = (optimal_reward - UCBPI.mean()).values[0]
    TS_mean = (optimal_reward - TS.mean()).values[0]
    EG_1_mean = (optimal_reward - EG_1.mean()).values[0]
    EG_2_mean = (optimal_reward - EG_2.mean()).values[0]
    EG_3_mean = (optimal_reward - EG_3.mean()).values[0]
    
    T = np.arange(EG_1.shape[1])
    trial = EG_1.shape[0]
    
    plt.figure(figsize=(30,20))
    sns.set(font_scale=2, style='white')
    
    plt.plot(EG_1_mean,alpha=1,color='#000000', linestyle='-')
    plt.plot(EG_2_mean,alpha=1,color='#000000', linestyle='-.')    
    plt.plot(EG_3_mean,alpha=1,color='#000000', linestyle='--')
    
    plt.plot(TS_mean,alpha=1,color='#666666', linestyle='-')
    
    plt.plot(UCB_1_mean,alpha=1,color='#666600', linestyle='-')
    plt.plot(UCB_2_mean,alpha=1,color='#666600', linestyle='-.')
    plt.plot(UCBT_mean,alpha=1,color='#666600', linestyle='--')
    plt.plot(UCBPI_mean,alpha=1,color='#666600', linestyle=':')


    plt.plot(IDS_1_mean,alpha=1,color='#FF6666', linestyle='-')
    plt.plot(IDS_2_mean,alpha=1,color='#FF6666', linestyle='-.')
    plt.plot(IDS_3_mean,alpha=1,color='#FF6666', linestyle='--')
    plt.plot(IDST_1_mean,alpha=1,color='#FF6666', linestyle=':')
    plt.plot(IDSN_mean,alpha=1,color='#0000FF', linestyle='-')
    plt.plot(IDSW_mean,alpha=1,color='#FFA500', linestyle='-')
    
    if bounds:
        plt.fill_between(T, get_low(optimal_reward, EG_1), get_high(optimal_reward, EG_1), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, EG_2), get_high(optimal_reward, EG_2), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, EG_3), get_high(optimal_reward, EG_3), color='#000000', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, TS), get_high(optimal_reward, TS), color='#666666', alpha=0.1)
        plt.fill_between(T, get_low(optimal_reward, UCB_1), get_high(optimal_reward, UCB_1), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCB_2), get_high(optimal_reward, UCB_2), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCBT), get_high(optimal_reward, UCBT), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, UCBPI), get_high(optimal_reward, UCBPI), color='#666600', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_1), get_high(optimal_reward, IDS_1), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_2), get_high(optimal_reward, IDS_2), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDS_3), get_high(optimal_reward, IDS_3), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDST_1), get_high(optimal_reward, IDST_1), color='#FF6666', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDSN), get_high(optimal_reward, IDSN), color='#0000FF', alpha=0.2)
        plt.fill_between(T, get_low(optimal_reward, IDSW), get_high(optimal_reward, IDSW), color='#FFA500', alpha=0.2)
        
        
        
    plt.legend(['EG_1', 'EG_2', 'EG_3', 'TS', 'UCB1', 'UCB2', 'UCB-tuned',
                'UCBPI', 'IDS_1 L=2, n=1', 'IDS2 L=4, n=1', 'IDS L=2, n=2',
                'IDS Theta', 'IDS without Transferability Test', 'IDS widnow Likelihood'],
              bbox_to_anchor=(1, -0.05), ncol=7, fancybox=True)
    plt.title(title)
    plt.xlabel('Horizon')
    plt.ylabel('Cumulative Regret')
    plt.show()

# %%
title = 'Case 6: Distribution Shift'
draw_regret(optimal_reward, IDS_1_df, IDS_2_df, IDS_3_df, IDST_1_df, IDSN_df, IDSW_df, UCB_1_df, UCB_2_df, UCBT_df,UCBPI_df,TS_df,EG_1_df, EG_2_df, EG_3_df, title, bounds=True)

# %%
def draw_arm(IDSN, IDSW, IDS, TS, UCB, EG):
    sns.set(font_scale=1.5, style='white')
    figure, axis = plt.subplots(2, 3, figsize=(20,12))

    trial = EG.shape[0]
    X = np.arange(EG.shape[1])
    for i in range(trial):
        axis[0, 0].scatter(x=X, y=IDSN.iloc[i], alpha=0.1, s=10, color='#0000FF')
    axis[0, 0].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[0, 0].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[0, 0].set_ylim([-1, 20])
    axis[0, 0].set_ylabel('Pulled Arms')
    axis[0, 0].set_title('IDS Without Transferability Test')
    
    for i in range(trial):
        axis[0, 1].scatter(x=X, y=IDS.iloc[i], alpha=0.1, s=10, color='#FF6666')
    axis[0, 1].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[0, 1].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[0, 1].set_ylim([-1, 20])
    axis[0, 1].set_ylabel('Pulled Arms')
    axis[0, 1].set_title('IDS')
    
    for i in range(trial):
        axis[0, 2].scatter(x=X, y=IDSW.iloc[i], alpha=0.1, s=10, color='#FFA500')
    axis[0, 2].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[0, 2].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[0, 2].set_ylim([-1, 20])
    axis[0, 2].set_ylabel('Pulled Arms')
    axis[0, 2].set_title('IDS Variant')

    for i in range(trial):
        axis[1, 0].scatter(x=X, y=TS.iloc[i], alpha=0.1, s=10, color='#666666')
    axis[1, 0].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[1, 0].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[1, 0].set_ylim([-1, 20])
    axis[1, 0].set_ylabel('Pulled Arms')
    axis[1, 0].set_title('TS')

    for i in range(trial):
        axis[1, 1].scatter(x=X, y=UCB.iloc[i], alpha=0.1, s=10, color='#666600')
    axis[1, 1].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[1, 1].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[1, 1].set_ylim([-1, 20])
    axis[1, 1].set_ylabel('Pulled Arms')
    axis[1, 1].set_title('UCB')

    for i in range(trial):
        axis[1, 2].scatter(x=X, y=EG.iloc[i], alpha=0.1, s=10, color='#996633')
    axis[1, 2].hlines(y=5, xmin=0, xmax=1000, color='r', linestyle='--', linewidth=3)
    axis[1, 2].hlines(y=12,xmin=1000, xmax=2000, color='r', linestyle='--', linewidth=3)
    axis[1, 2].set_ylim([-1, 20])
    axis[1, 2].set_ylabel('Pulled Arms')
    axis[1, 2].set_title('EG')

    figure.text(0.5, 0.05, 'Horizon')
    plt.show()

# %%
draw_arm(IDSN_df_arm, IDSW_df_arm, IDS_3_df_arm, UCB_2_df_arm, TS_df_arm, EG_1_df_arm)

# %%
#Est
sns.set(font_scale=1.2, style='white')
plt.figure(figsize=(12,8))
sns.lineplot(data=IDS_1.get_p_a_y() @ np.linspace(1, 10, 11) / 10, color='blue')
sns.lineplot(data=IDST_1.get_p_a_y() @ np.linspace(1, 10, 11) / 10, color='green')
#True
df2['demand'] = df2['reward'] / df2['price']
sns.lineplot(data=df2.groupby('arm').demand.mean()/10, color='red')
plt.ylabel('Demand')
plt.xlabel('Arm')
plt.xticks(np.arange(20))
plt.show()

# %%
#Est
plt.figure(figsize=(12,8))
sns.lineplot(data=IDS_1.get_p_a_y() @ np.linspace(1, 10, 11) * price_list, color='blue')
sns.lineplot(data=IDST_1.get_p_a_y() @ np.linspace(1, 10, 11) * price_list, color='green')
#True
df2['demand'] = df2['reward'] / df2['price']
sns.lineplot(data=df2.groupby('arm').demand.mean() * price_list, color='red')
plt.ylabel('Expected Revenue ($/ 10 customers)')
plt.xlabel('Arm')
plt.xticks(np.arange(20))
plt.show()
